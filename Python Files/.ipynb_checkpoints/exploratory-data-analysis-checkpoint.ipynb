# %% [markdown]
# # Exploratory Data Analysis of Similarity Data

# %%
# Import necessary libraries
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import random, itertools as it
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# ## Similarity Distribution of Nodes

# %%
dist_1 = pd.read_csv("Experiment - Similarity Distribution of Nodes/Data/sim-dist-nodes-40-60_1.csv", header=[0], index_col=[0])
dist_1.tail()
# Out:
#       Edit-Distance Immediate Similarity  Edit-Distance Full Similarity  \
# 1555                                 0.0                       0.124972
# 1556                                 0.0                       0.000000
# 1557                                 1.0                       1.000000
# 1558                                 0.0                       0.000000
# 1559                                 1.0                       1.000000
#
#       Jaccard Index Similarity  Longest Maximal Independent Set  \
# 1555                  0.022305                               24
# 1556                  0.000000                               24
# 1557                  0.000000                               24
# 1558                  0.000000                               24
# 1559                  0.000000                               24
#
#       Number of Maximal Cliques  Longest Maximal Clique
# 1555                      37440                       3
# 1556                      37440                       3
# 1557                      37440                       3
# 1558                      37440                       3
# 1559                      37440                       3

# %%
dist_1.describe()
# Out:
#        Edit-Distance Immediate Similarity  Edit-Distance Full Similarity  \
# count                         1560.000000                    1560.000000
# mean                             0.310638                       0.471301
# std                              0.457066                       0.436901
# min                              0.000000                       0.000000
# 25%                              0.000000                       0.000000
# 50%                              0.000000                       0.361975
# 75%                              1.000000                       1.000000
# max                              1.000000                       1.000000
#
#        Jaccard Index Similarity  Longest Maximal Independent Set  \
# count               1560.000000                           1560.0
# mean                   0.059237                             24.0
# std                    0.117924                              0.0
# min                    0.000000                             24.0
# 25%                    0.000000                             24.0
# 50%                    0.000000                             24.0
# 75%                    0.071765                             24.0
# max                    0.834170                             24.0
#
#        Number of Maximal Cliques  Longest Maximal Clique
# count                     1560.0                  1560.0
# mean                     37440.0                     3.0
# std                          0.0                     0.0
# min                      37440.0                     3.0
# 25%                      37440.0                     3.0
# 50%                      37440.0                     3.0
# 75%                      37440.0                     3.0
# max                      37440.0                     3.0

# %%
dist_1.boxplot(column=["Edit-Distance Immediate Similarity", "Edit-Distance Full Similarity", 'Jaccard Index Similarity'], figsize = (15,6), return_type = "axes")

plt.ylabel("Similarity")
plt.xlabel("(Using a Randomly Generated Directed Graphical Models with 40 nodes and 60 edges)")
plt.title("Similarity of Nodes in a Single Directed Graphical Model")
# plt.ylim(0, 1)
plt.savefig('Experiment - Similarity Distribution of Nodes/sim-dist-nodes-40-60_1.png')

# %%
dist_2 = pd.read_csv("Experiment - Similarity Distribution of Nodes/Data/sim-dist-nodes-40-60_2.csv", header=[0], index_col=[0])

# %%
dist_2.describe()
# Out:
#        Edit-Distance Immediate Similarity  Edit-Distance Full Similarity  \
# count                         1560.000000                    1560.000000
# mean                             0.339675                       0.526479
# std                              0.465711                       0.442617
# min                              0.000000                       0.000000
# 25%                              0.000000                       0.000000
# 50%                              0.000000                       0.638917
# 75%                              1.000000                       1.000000
# max                              1.000000                       1.000000
#
#        Jaccard Index Similarity  Longest Maximal Independent Set  \
# count               1560.000000                           1560.0
# mean                   0.063868                             24.0
# std                    0.141668                              0.0
# min                    0.000000                             24.0
# 25%                    0.000000                             24.0
# 50%                    0.000000                             24.0
# 75%                    0.038168                             24.0
# max                    0.909024                             24.0
#
#        Number of Maximal Cliques  Longest Maximal Clique
# count                     1560.0                  1560.0
# mean                     40560.0                     2.0
# std                          0.0                     0.0
# min                      40560.0                     2.0
# 25%                      40560.0                     2.0
# 50%                      40560.0                     2.0
# 75%                      40560.0                     2.0
# max                      40560.0                     2.0

# %%
dist_2.boxplot(column=["Edit-Distance Immediate Similarity", "Edit-Distance Full Similarity", 'Jaccard Index Similarity'], figsize = (15,6), return_type = "axes")

plt.ylabel("Similarity")
plt.xlabel("(Using a Randomly Generated Directed Graphical Models with 40 nodes and 60 edges)")
plt.title("Similarity of Nodes in a Single Directed Graphical Model")
# plt.ylim(0, 1)
plt.savefig('Experiment - Similarity Distribution of Nodes/sim-dist-nodes-40-60_2.png')

# %% [markdown]
# ## Similarity Distribution of Graphs

# %%
dist_1 = pd.read_csv("Experiment - Similarity Distribution/Data/sim-dist-25-40-60.csv", header=[0, 1], index_col=[0])
dist_1.head()
# Out:
#              Edit-Distance Immediate Similarity                 \
#                                            mean  50%       std
# Graph Number
# 0                                      0.246028  0.0  0.419024
# 1                                      0.317401  0.0  0.457178
# 2                                      0.221097  0.0  0.404108
# 3                                      0.266765  0.0  0.434282
# 4                                      0.192601  0.0  0.384927
#
#              Edit-Distance Full Similarity                      \
#                                       mean       50%       std
# Graph Number
# 0                                 0.476010  0.446358  0.417461
# 1                                 0.470919  0.338988  0.440665
# 2                                 0.624605  0.768202  0.375302
# 3                                 0.517063  0.538165  0.405231
# 4                                 0.611431  0.821620  0.395385
#
#              Jaccard Index Similarity                      \
#                                  mean       50%       std
# Graph Number
# 0                            0.131491  0.012250  0.245162
# 1                            0.072276  0.000000  0.135305
# 2                            0.265402  0.253515  0.264665
# 3                            0.183638  0.000000  0.248456
# 4                            0.277664  0.248835  0.269398
#
#              Longest Maximal Independent Set             \
#                                         mean   50%  std
# Graph Number
# 0                                       27.0  27.0  0.0
# 1                                       31.0  31.0  0.0
# 2                                       26.0  26.0  0.0
# 3                                       26.0  26.0  0.0
# 4                                       28.0  28.0  0.0
#
#              Number of Maximal Cliques               Longest Maximal Clique  \
#                                   mean      50%  std                   mean
# Graph Number
# 0                              35880.0  35880.0  0.0                    2.0
# 1                              35880.0  35880.0  0.0                    3.0
# 2                              39000.0  39000.0  0.0                    2.0
# 3                              35880.0  35880.0  0.0                    3.0
# 4                              37440.0  37440.0  0.0                    2.0
#
#
#               50%  std
# Graph Number
# 0             2.0  0.0
# 1             3.0  0.0
# 2             2.0  0.0
# 3             3.0  0.0
# 4             2.0  0.0

# %%
main_col_list = list({col_pair[0] for col_pair in dist_1.columns})
mean_data = {}

for col in main_col_list:
    mean_data[col] = dist_1[(col, "mean")]

mean_dist_1 = pd.DataFrame(data = mean_data)

# %%
mean_dist_1.head()
# Out:
#               Number of Maximal Cliques  Jaccard Index Similarity  \
# Graph Number
# 0                               35880.0                  0.131491
# 1                               35880.0                  0.072276
# 2                               39000.0                  0.265402
# 3                               35880.0                  0.183638
# 4                               37440.0                  0.277664
#
#               Longest Maximal Independent Set  \
# Graph Number
# 0                                        27.0
# 1                                        31.0
# 2                                        26.0
# 3                                        26.0
# 4                                        28.0
#
#               Edit-Distance Immediate Similarity  \
# Graph Number
# 0                                       0.246028
# 1                                       0.317401
# 2                                       0.221097
# 3                                       0.266765
# 4                                       0.192601
#
#               Edit-Distance Full Similarity  Longest Maximal Clique
# Graph Number
# 0                                  0.476010                     2.0
# 1                                  0.470919                     3.0
# 2                                  0.624605                     2.0
# 3                                  0.517063                     3.0
# 4                                  0.611431                     2.0

# %%
mean_dist_1.boxplot(column=["Edit-Distance Immediate Similarity", "Edit-Distance Full Similarity", 'Jaccard Index Similarity'], figsize = (15,6), return_type = "axes")

plt.ylabel("Similarity")
plt.xlabel("(Using 25 Randomly Generated Directed Graphical Models with 40 nodes and 60 edges)")
plt.title("Similarity of Randomly Generated Directed Graphical Models")
plt.ylim(0, 1)
plt.savefig('Experiment - Similarity Distribution/sim-dist-25-40-60.png')

# %%
dist_2 = pd.read_csv("Experiment - Similarity Distribution/Data/sim-dist-50-100-150.csv", header=[0, 1], index_col=[0])
dist_2.head()
# Out:
#              Edit-Distance Immediate Similarity                 \
#                                            mean  50%       std
# Graph Number
# 0                                      0.277410  0.0  0.443734
# 1                                      0.296392  0.0  0.453256
# 2                                      0.248523  0.0  0.427635
# 3                                      0.228130  0.0  0.415035
# 4                                      0.237379  0.0  0.421441
#
#              Edit-Distance Full Similarity                      \
#                                       mean       50%       std
# Graph Number
# 0                                 0.463912  0.381159  0.444924
# 1                                 0.512786  0.607416  0.443977
# 2                                 0.490853  0.532239  0.430373
# 3                                 0.457820  0.414504  0.441271
# 4                                 0.478411  0.450571  0.430786
#
#              Jaccard Index Similarity                 \
#                                  mean  50%       std
# Graph Number
# 0                            0.090557  0.0  0.184244
# 1                            0.119374  0.0  0.213844
# 2                            0.128615  0.0  0.218947
# 3                            0.121561  0.0  0.221989
# 4                            0.092798  0.0  0.196930
#
#              Longest Maximal Independent Set             \
#                                         mean   50%  std
# Graph Number
# 0                                       66.0  66.0  0.0
# 1                                       61.0  61.0  0.0
# 2                                       64.0  64.0  0.0
# 3                                       62.0  62.0  0.0
# 4                                       65.0  65.0  0.0
#
#              Number of Maximal Cliques                Longest Maximal Clique  \
#                                   mean       50%  std                   mean
# Graph Number
# 0                             594000.0  594000.0  0.0                    3.0
# 1                             584100.0  584100.0  0.0                    3.0
# 2                             584100.0  584100.0  0.0                    3.0
# 3                             643500.0  643500.0  0.0                    2.0
# 4                             613800.0  613800.0  0.0                    2.0
#
#
#               50%  std
# Graph Number
# 0             3.0  0.0
# 1             3.0  0.0
# 2             3.0  0.0
# 3             2.0  0.0
# 4             2.0  0.0

# %%
main_col_list = list({col_pair[0] for col_pair in dist_2.columns})
mean_data = {}

for col in main_col_list:
    mean_data[col] = dist_2[(col, "mean")]

mean_dist_2 = pd.DataFrame(data = mean_data)

# %%
mean_dist_2.boxplot(column=["Edit-Distance Immediate Similarity", "Edit-Distance Full Similarity", 'Jaccard Index Similarity'], figsize = (15,6), return_type = "axes")

plt.ylabel("Similarity")
plt.xlabel("(Using 50 Randomly Generated Directed Graphical Models with 100 nodes and 150 edges)")
plt.title("Similarity of Randomly Generated Directed Graphical Models")
plt.ylim(0, 1)
plt.savefig('Experiment - Similarity Distribution/sim-dist-50-100-150.png')

# %% [markdown]
# ## Similarity Distribution Over Varying Graph Sizes

# %%
dist_1 = pd.read_csv("Experiment - Graph Size Distribution/Data/graph-size-dist-20-10-41-10.csv", header=[0, 1], index_col=[0,1])
dist_2 = pd.read_csv("Experiment - Graph Size Distribution/Data/graph-size-dist-10-70-101-10.csv", header=[0, 1], index_col=[0,1])
dist_2.head()
# Out:
#                                            Edit-Distance Immediate Similarity  \
#                                                                          mean
# Number of Nodes Per Graph Number of Graphs
# 70                        10                                         0.374622
# 80                        10                                         0.365455
# 90                        10                                         0.371920
# 100                       10                                         0.373796
#
#                                                                 \
#                                                  50%       std
# Number of Nodes Per Graph Number of Graphs
# 70                        10                0.378173  0.054223
# 80                        10                0.356353  0.031500
# 90                        10                0.375763  0.036006
# 100                       10                0.374148  0.036719
#
#                                            Edit-Distance Full Similarity  \
#                                                                     mean
# Number of Nodes Per Graph Number of Graphs
# 70                        10                                    0.452240
# 80                        10                                    0.440886
# 90                        10                                    0.435935
# 100                       10                                    0.442686
#
#                                                                 \
#                                                  50%       std
# Number of Nodes Per Graph Number of Graphs
# 70                        10                0.445559  0.042189
# 80                        10                0.446142  0.039364
# 90                        10                0.439146  0.019060
# 100                       10                0.449974  0.039849
#
#                                            Jaccard Index Similarity            \
#                                                                mean       50%
# Number of Nodes Per Graph Number of Graphs
# 70                        10                               0.034452  0.036431
# 80                        10                               0.037367  0.038063
# 90                        10                               0.029177  0.029486
# 100                       10                               0.032939  0.029126
#
#                                                       \
#                                                  std
# Number of Nodes Per Graph Number of Graphs
# 70                        10                0.015623
# 80                        10                0.017089
# 90                        10                0.010049
# 100                       10                0.009890
#
#                                            Longest Maximal Independent Set  \
#                                                                       mean
# Number of Nodes Per Graph Number of Graphs
# 70                        10                                          49.1
# 80                        10                                          56.1
# 90                        10                                          63.2
# 100                       10                                          70.1
#
#                                                             \
#                                              50%       std
# Number of Nodes Per Graph Number of Graphs
# 70                        10                49.0  2.024846
# 80                        10                56.5  2.558211
# 90                        10                63.5  1.398412
# 100                       10                70.0  1.791957
#
#                                            Number of Maximal Cliques  \
#                                                                 mean
# Number of Nodes Per Graph Number of Graphs
# 70                        10                                220731.0
# 80                        10                                329904.0
# 90                        10                                466182.0
# 100                       10                                643500.0
#
#                                                                     \
#                                                  50%           std
# Number of Nodes Per Graph Number of Graphs
# 70                        10                219765.0   6849.599258
# 80                        10                328640.0   8320.666640
# 90                        10                464580.0  14526.370503
# 100                       10                643500.0  16826.764395
#
#                                            Longest Maximal Clique       \
#                                                              mean  50%
# Number of Nodes Per Graph Number of Graphs
# 70                        10                                  2.3  2.0
# 80                        10                                  2.4  2.0
# 90                        10                                  2.2  2.0
# 100                       10                                  2.3  2.0
#
#
#                                                  std
# Number of Nodes Per Graph Number of Graphs
# 70                        10                0.483046
# 80                        10                0.516398
# 90                        10                0.421637
# 100                       10                0.483046

# %%
distributions = [dist_1, dist_2]

dist = pd.concat(distributions)

# %%
dist["Edit-Distance Immediate Similarity"]["mean"]
# Out:
# Number of Nodes Per Graph  Number of Graphs
# 10                         20                  0.459189
# 20                         20                  0.432411
# 30                         20                  0.395798
# 40                         20                  0.390805
# 70                         10                  0.374622
# 80                         10                  0.365455
# 90                         10                  0.371920
# 100                        10                  0.373796
# Name: mean, dtype: float64

# %%
fig = plt.figure(figsize = (12, 8))
ax = fig.add_subplot(111)

ed_imm_sim = list(dist["Edit-Distance Immediate Similarity"]["mean"])
ed_f_sim = list(dist["Edit-Distance Full Similarity"]["mean"])
ji_sim = list(dist["Jaccard Index Similarity"]["mean"])

ed_imm_sim_std = list(dist["Edit-Distance Immediate Similarity"]["std"])
ed_f_sim_std = list(dist["Edit-Distance Full Similarity"]["std"])
ji_sim_std = list(dist["Jaccard Index Similarity"]["std"])

# Adapted from https://stackoverflow.com/questions/14270391/python-matplotlib-multiple-bars
N = len(ed_imm_sim)
ind = np.arange(N)  # the x locations for the groups
width = 0.27       # the width of the bars
index_1_list = [value_pair[0] for value_pair in dist.index.values.tolist()]

# ed_imm_sim = dist["Edit-Distance Immediate Similarity"]["mean"]
# ed_f_sim = dist["Edit-Distance Full Similarity"]["mean"]
# ji_sim = dist["Jaccard Index Similarity"]["mean"]

# ed_imm_sim_std = dist["Edit-Distance Immediate Similarity"]["std"]
# ed_f_sim_std = dist["Edit-Distance Full Similarity"]["std"]
# ji_sim_std = dist["Jaccard Index Similarity"]["std"]

# print(ji_sim_std.shape == ji_sim.shape)
# print(len(ed_imm_sim) == len(ji_sim_std))

rects1 = ax.bar(ind, ed_imm_sim, width, color='r', yerr=ed_imm_sim_std)
rects2 = ax.bar(ind + width, ed_f_sim, width, color='g', yerr=ed_f_sim_std)
rects3 = ax.bar(ind + width * 2, ji_sim, width, color='b', yerr=ji_sim_std)

ax.set_ylabel('Similarity')
ax.set_xlabel("Graph Size (Number of Nodes)")
ax.set_xticks(ind + width)
ax.set_xticklabels(index_1_list)
ax.legend((rects1[0], rects2[0], rects3[0]), ('Edit-Distance Immediate Similarity', 'Edit-Distance Full Similarity', 'Jaccard Index Similarity'))
ax.set_ylim(0, 1)
ax.set_title("Similarity vs. Graph Size")

plt.savefig("Experiment - Graph Size Distribution/graph-size-dist-20-10-101-10.png")

plt.show()

# %% [markdown]
# ## Similarity Distribution Over Edge Factor

# %%
dist = pd.read_csv("Experiment - Edges Factor/Data/edges-factor-dist-10-40-1.0-3.1-0.5.csv", header=[0, 1], index_col=[0,1,2,3])
dist.head()
# Out:
#                                                                                            Edit-Distance Immediate Similarity  \
#                                                                                                                          mean
# Nodes To Edges Factor Number of Nodes Per Graph Number of Edges Per Graph Number of Graphs
# 1.0                   40                        40                        10                                         0.373313
# 1.5                   40                        60                        10                                         0.298748
# 2.0                   40                        80                        10                                         0.199090
# 2.5                   40                        100                       10                                         0.180906
# 3.0                   40                        120                       10                                         0.153480
#
#                                                                                                       \
#                                                                                                  50%
# Nodes To Edges Factor Number of Nodes Per Graph Number of Edges Per Graph Number of Graphs
# 1.0                   40                        40                        10                0.371480
# 1.5                   40                        60                        10                0.289763
# 2.0                   40                        80                        10                0.209640
# 2.5                   40                        100                       10                0.178133
# 3.0                   40                        120                       10                0.148977
#
#                                                                                                       \
#                                                                                                  std
# Nodes To Edges Factor Number of Nodes Per Graph Number of Edges Per Graph Number of Graphs
# 1.0                   40                        40                        10                0.042068
# 1.5                   40                        60                        10                0.057778
# 2.0                   40                        80                        10                0.032448
# 2.5                   40                        100                       10                0.032027
# 3.0                   40                        120                       10                0.032395
#
#                                                                                            Edit-Distance Full Similarity  \
#                                                                                                                     mean
# Nodes To Edges Factor Number of Nodes Per Graph Number of Edges Per Graph Number of Graphs
# 1.0                   40                        40                        10                                    0.466152
# 1.5                   40                        60                        10                                    0.496696
# 2.0                   40                        80                        10                                    0.538316
# 2.5                   40                        100                       10                                    0.591252
# 3.0                   40                        120                       10                                    0.593023
#
#                                                                                                       \
#                                                                                                  50%
# Nodes To Edges Factor Number of Nodes Per Graph Number of Edges Per Graph Number of Graphs
# 1.0                   40                        40                        10                0.469957
# 1.5                   40                        60                        10                0.485395
# 2.0                   40                        80                        10                0.547496
# 2.5                   40                        100                       10                0.595294
# 3.0                   40                        120                       10                0.600868
#
#                                                                                                       \
#                                                                                                  std
# Nodes To Edges Factor Number of Nodes Per Graph Number of Edges Per Graph Number of Graphs
# 1.0                   40                        40                        10                0.052832
# 1.5                   40                        60                        10                0.038957
# 2.0                   40                        80                        10                0.040960
# 2.5                   40                        100                       10                0.039598
# 3.0                   40                        120                       10                0.040299
#
#                                                                                            Jaccard Index Similarity  \
#                                                                                                                mean
# Nodes To Edges Factor Number of Nodes Per Graph Number of Edges Per Graph Number of Graphs
# 1.0                   40                        40                        10                               0.046176
# 1.5                   40                        60                        10                               0.092144
# 2.0                   40                        80                        10                               0.162922
# 2.5                   40                        100                       10                               0.226943
# 3.0                   40                        120                       10                               0.219846
#
#                                                                                                       \
#                                                                                                  50%
# Nodes To Edges Factor Number of Nodes Per Graph Number of Edges Per Graph Number of Graphs
# 1.0                   40                        40                        10                0.049905
# 1.5                   40                        60                        10                0.087294
# 2.0                   40                        80                        10                0.163104
# 2.5                   40                        100                       10                0.217337
# 3.0                   40                        120                       10                0.205030
#
#                                                                                                       \
#                                                                                                  std
# Nodes To Edges Factor Number of Nodes Per Graph Number of Edges Per Graph Number of Graphs
# 1.0                   40                        40                        10                0.021719
# 1.5                   40                        60                        10                0.034007
# 2.0                   40                        80                        10                0.028674
# 2.5                   40                        100                       10                0.055689
# 3.0                   40                        120                       10                0.068542
#
#                                                                                            Longest Maximal Independent Set  \
#                                                                                                                       mean
# Nodes To Edges Factor Number of Nodes Per Graph Number of Edges Per Graph Number of Graphs
# 1.0                   40                        40                        10                                          28.6
# 1.5                   40                        60                        10                                          25.3
# 2.0                   40                        80                        10                                          23.4
# 2.5                   40                        100                       10                                          21.8
# 3.0                   40                        120                       10                                          20.6
#
#                                                                                                   \
#                                                                                              50%
# Nodes To Edges Factor Number of Nodes Per Graph Number of Edges Per Graph Number of Graphs
# 1.0                   40                        40                        10                29.0
# 1.5                   40                        60                        10                25.5
# 2.0                   40                        80                        10                24.0
# 2.5                   40                        100                       10                21.5
# 3.0                   40                        120                       10                20.5
#
#                                                                                                       \
#                                                                                                  std
# Nodes To Edges Factor Number of Nodes Per Graph Number of Edges Per Graph Number of Graphs
# 1.0                   40                        40                        10                1.505545
# 1.5                   40                        60                        10                2.790858
# 2.0                   40                        80                        10                1.505545
# 2.5                   40                        100                       10                2.149935
# 3.0                   40                        120                       10                2.366432
#
#                                                                                            Number of Maximal Cliques  \
#                                                                                                                 mean
# Nodes To Edges Factor Number of Nodes Per Graph Number of Edges Per Graph Number of Graphs
# 1.0                   40                        40                        10                                 40716.0
# 1.5                   40                        60                        10                                 37752.0
# 2.0                   40                        80                        10                                 34476.0
# 2.5                   40                        100                       10                                 33228.0
# 3.0                   40                        120                       10                                 31356.0
#
#                                                                                                      \
#                                                                                                 50%
# Nodes To Edges Factor Number of Nodes Per Graph Number of Edges Per Graph Number of Graphs
# 1.0                   40                        40                        10                40560.0
# 1.5                   40                        60                        10                39000.0
# 2.0                   40                        80                        10                34320.0
# 2.5                   40                        100                       10                34320.0
# 3.0                   40                        120                       10                31200.0
#
#                                                                                                          \
#                                                                                                     std
# Nodes To Edges Factor Number of Nodes Per Graph Number of Edges Per Graph Number of Graphs
# 1.0                   40                        40                        10                2377.258926
# 1.5                   40                        60                        10                2181.522404
# 2.0                   40                        80                        10                2260.654772
# 2.5                   40                        100                       10                2444.553129
# 3.0                   40                        120                       10                1867.661640
#
#                                                                                            Longest Maximal Clique  \
#                                                                                                              mean
# Nodes To Edges Factor Number of Nodes Per Graph Number of Edges Per Graph Number of Graphs
# 1.0                   40                        40                        10                                  2.4
# 1.5                   40                        60                        10                                  2.7
# 2.0                   40                        80                        10                                  2.9
# 2.5                   40                        100                       10                                  3.0
# 3.0                   40                        120                       10                                  3.0
#
#                                                                                                  \
#                                                                                             50%
# Nodes To Edges Factor Number of Nodes Per Graph Number of Edges Per Graph Number of Graphs
# 1.0                   40                        40                        10                2.0
# 1.5                   40                        60                        10                3.0
# 2.0                   40                        80                        10                3.0
# 2.5                   40                        100                       10                3.0
# 3.0                   40                        120                       10                3.0
#
#
#                                                                                                  std
# Nodes To Edges Factor Number of Nodes Per Graph Number of Edges Per Graph Number of Graphs
# 1.0                   40                        40                        10                0.516398
# 1.5                   40                        60                        10                0.483046
# 2.0                   40                        80                        10                0.316228
# 2.5                   40                        100                       10                0.000000
# 3.0                   40                        120                       10                0.000000

# %%
fig = plt.figure(figsize = (12, 8))
ax = fig.add_subplot(111)

ed_imm_sim = list(dist["Edit-Distance Immediate Similarity"]["mean"])
ed_f_sim = list(dist["Edit-Distance Full Similarity"]["mean"])
ji_sim = list(dist["Jaccard Index Similarity"]["mean"])

ed_imm_sim_std = list(dist["Edit-Distance Immediate Similarity"]["std"])
ed_f_sim_std = list(dist["Edit-Distance Full Similarity"]["std"])
ji_sim_std = list(dist["Jaccard Index Similarity"]["std"])

# Adapted from https://stackoverflow.com/questions/14270391/python-matplotlib-multiple-bars
N = len(ed_imm_sim)
ind = np.arange(N)  # the x locations for the groups
width = 0.27       # the width of the bars
index_1_list = [value_pair[0] for value_pair in dist.index.values.tolist()]

rects1 = ax.bar(ind, ed_imm_sim, width, color='r', yerr=ed_imm_sim_std)
rects2 = ax.bar(ind + width, ed_f_sim, width, color='g', yerr=ed_f_sim_std)
rects3 = ax.bar(ind + width * 2, ji_sim, width, color='b', yerr=ji_sim_std)

ax.set_ylabel('Similarity')
ax.set_xlabel("Nodes To Edges Factor")
ax.set_xticks(ind + width)
ax.set_xticklabels(index_1_list)
ax.legend((rects1[0], rects2[0], rects3[0]), ('Edit-Distance Immediate Similarity', 'Edit-Distance Full Similarity', 'Jaccard Index Similarity'))
ax.set_ylim(0, 1)
ax.set_title("Similarity vs. Nodes To Edges Factor")

plt.savefig("Experiment - Edges Factor/edges-factor-dist-10-40-1.0-3.1-0.5.png")

plt.show()
