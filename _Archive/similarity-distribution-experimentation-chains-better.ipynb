# %% [markdown]
# # Graphical Models: Similarity Distribution Experimentation

# %%
# Import necessary libraries
import networkx as nx
import matplotlib.pyplot as plt
import random

# %% [markdown]
# ## Similarity Implementations

# %% [markdown]
# ### General Methods

# %%
# get all children in a dictionary including their respective weights (chains taken into account)
def get_all_children(graph, parent, children_dict={}, carry=1):
    weights = nx.get_edge_attributes(graph, 'weight')
    for i in graph.out_edges(parent):
        children_dict[i[1]] = carry*weights[i]
        get_all_children(graph, i[1], children_dict=children_dict, carry=weights[i])
    return children_dict

# %%
# (Adapted from function above)
# Get all children in a dictionary including their respective weights (chains taken into account)
def get_descendants(graph, parent, children_dict={}, carry=1):
    weights = nx.get_edge_attributes(graph, 'weight')
    
    for i in graph.out_edges(parent):
        children_dict[i[1]] = carry*weights[i]
        get_descendants(graph, i[1], children_dict=children_dict, carry=weights[i])
    
    return children_dict

# %%
# Returns children of a single node
def get_children(gm, parent):
    children_weights = {}
    weights = nx.get_edge_attributes(gm, 'weight')
    
    for i in gm.out_edges(parent):
        children_weights[i[1]] = weights[i]

    return children_weights

# %%
def find_node_children_subgraph(graph, snode, childgraph):
    cnodes = graph.neighbors(snode)
    edges = nx.edges(graph)
    for i in cnodes:
        childgraph.add_node(i)
        childgraph.add_edge(snode, i)
        childgraph = find_node_children_subgraph(graph, i, childgraph)
    return childgraph

# %% [markdown]
# ### Jaccard Index

# %%
# all children of rain
def calculate_intersection(graph, children_a, children_b):
    inter = 0
    for i in children_a:
        if i in children_b:
            if children_a[i] < children_b[i]:
                inter += children_a[i]
            else:
                inter += children_b[i]
    return inter

# %%
# helper func to calculate the union using method 1
def calculate_union_1(graph, children_a, children_b):
    union = 0
    for i in children_a:
        union += children_a[i]
    for i in children_b:
        union += children_b[i]
    union -= calculate_intersection(graph, children_a, children_b)
    return union

# %%
# calculate the similarity, compares both methods
def calculate_jaccard_similarity(graph, node_a, node_b):
    children_a = get_all_children(graph, node_a, {})
    children_b = get_all_children(graph, node_b, {})
    intersection = calculate_intersection(graph, children_a, children_b)
    union = calculate_union_1(graph, children_a, children_b)
    if union == 0:
        total = 0
    else:
        total = intersection/union
    return total

# %% [markdown]
# ### Edit-Distance

# %% [markdown]
# Edit-distance similarity implementation based only on a node's children.

# %%
# Returns the similarity of node B compared to node A, based on 
# children
def get_immediate_similarity(gm, A, B):
    cost = 0.0
    A_children = get_children(gm, A)
    B_children = get_children(gm, B)
    
    for child in A_children:
        if child in B_children:
            diff = abs(A_children[child] - B_children[child])
            cost += diff
        else:
            cost += 1
    
    return cost / len(A_children)

# %%
# Returns the node that is most similar to the input node
def find_most_immediate_similar(gm, A):
    nodes = list(gm.nodes)
    nodes.remove(A)
    
    max_similarity = get_immediate_similarity(gm, A, nodes[0])
    max_sim_node = nodes[0]
    for node in nodes:
        node_similarity = get_immediate_similarity(gm, A, node)
        
        if node_similarity < max_similarity:
            max_sim_node = node
            max_similarity = node_similarity
    
    return max_sim_node

# %% [markdown]
# Edit-distance similarity implementation based on all descendants of a node.

# %%
# Returns the similarity of node B compared to node A
def get_full_similarity(gm, A, B):
    cost = 0.0
    A_children = get_descendants(gm, A, {}, 1)
    B_children = get_descendants(gm, B, {}, 1)
    
    for child in A_children:
        if child in B_children:
            diff = abs(A_children[child] - B_children[child])
            cost += diff
        else:
            cost += 1
    return cost / len(A_children)

# Optional print line in for loop for debugging: 
# print(child, A_children[child], B_children[child])

# %%
# Returns the node that is most similar to the input node
def find_most_similar(gm, A):
    nodes = list(gm.nodes)
    nodes.remove(A)
    
    max_similarity = get_full_similarity(gm, A, nodes[0])
    max_sim_node = nodes[0]
    for node in nodes:
        node_similarity = get_full_similarity(gm, A, node)
        
        if node_similarity < max_similarity:
            max_sim_node = node
            max_similarity = node_similarity
    
    return max_sim_node

# %% [markdown]
# ### NetworkX: Edit-Distance

# %%
# nx.graph_edit_distance(Graph1, Graph2)

# %%
dd

# %% [markdown]
# ### NetworkX: SimRank

# %%
# nx.algorithms.similarity.simrank_similarity(graph, source="node_a", target="node_b")

# %% [markdown]
# ## Generating Random Directed Graphs

# %%
def addNodes(gm, num_nodes):
    node_list = []
    
    for i in range(num_nodes):
        gm.add_node(i)

    return gm

# %%
def addEdges(gm, num_nodes, num_edges):
    for i in range(num_edges):
        parent = random.randrange(num_nodes)
        child = random.randrange(num_nodes)
        
        while (child == parent):
            child = random.randrange(num_nodes)
        
        conditional_prob = random.uniform(0, 1)
        gm.add_edge(parent, child, weight=conditional_prob)
    
    return gm

# %%
def makeDirectedGraph(num_nodes, num_edges):
    dg = nx.DiGraph() # creates directed graph
    dg = addNodes(dg, num_nodes)
    dg = addEdges(dg, num_nodes, num_edges)
    return dg

# %%
def makeDirectedPath(num_nodes):
    pdg = nx.path_graph(num_nodes, create_using=nx.DiGraph())
    for i in pdg.edges():
        pdg.edges[i[0], i[1]]['weight'] = weight=random.uniform(0, 1)
    return pdg

def makeDirectedPathOne(num_nodes):
    pdg = nx.path_graph(num_nodes, create_using=nx.DiGraph())
    for i in pdg.edges():
        pdg.edges[i[0], i[1]]['weight'] = 1
    return pdg

# %%
def makeDirectedStarGraph(num_nodes):
    sdg = nx.DiGraph()
    sdg.add_node(0)
    for i in range(1, num_nodes+1):
        sdg.add_node(i)
        sdg.add_edge(0, i, weight=random.uniform(0, 1))
    return sdg

# %% [markdown]
# ## Experiment Setup

# %% [markdown]
# ### make directed graph

# %%
g = makeDirectedGraph(3, 3)

# %%
nx.edges(g)
# Out:
# OutEdgeView([(0, 1), (1, 0), (2, 0)])

# %%
nx.draw_networkx(g)

# %%
nx.get_edge_attributes(g, 'weight')
# Out:
# {(0, 1): 0.14540787984964176,
#  (1, 0): 0.1460172178772131,
#  (2, 0): 0.6016876084561853}

# %% [markdown]
# ### make directed path

# %%
pdg = makeDirectedPath(5)
nx.draw_networkx(pdg)

# %%
nx.get_edge_attributes(pdg, 'weight')
# Out:
# {(0, 1): 0.23749084505174733,
#  (1, 2): 0.9011869087331753,
#  (2, 3): 0.724034079653901,
#  (3, 4): 0.7948822843588877}

# %% [markdown]
# ## Tests
# test on paths of length 10, 50, 100, 500, and 1000

# %%
pdg = makeDirectedPath(10)
nums_10_nx = []
for i in pdg.nodes():
    nums_10_nx.append(nx.algorithms.similarity.simrank_similarity(pdg, source=0, target=i))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-95-7ad4bda48cf9> in <module>
#       2 nums_10_nx = []
#       3 for i in pdg.nodes():
# ----> 4     nums_10_nx.append(nx.algorithms.similarity.simrank_similarity(pdg, source=0, target=i))
#
# AttributeError: module 'networkx.algorithms.similarity' has no attribute 'simrank_similarity'

# %% [markdown]
# ### Jaccard

# %%
pdg = makeDirectedPath(10)
nums_10_jaccard = []
for i in pdg.nodes():
    nums_10_jaccard.append(calculate_jaccard_similarity(pdg, 0, i))
data = {"10 node jaccard": nums_10_jaccard}

# %%
import matplotlib.pyplot as plt
plt.plot(nums_10_jaccard)
plt.ylabel("jaccard similarity")
plt.show()

# %%
pdg = makeDirectedPath(50)
nums_50_jaccard = []
for i in pdg.nodes():
    nums_50_jaccard.append(calculate_jaccard_similarity(pdg, 0, i))
data['50 node jaccard'] = nums_50_jaccard

# %%
import matplotlib.pyplot as plt
plt.plot(nums_50_jaccard)
plt.ylabel("jaccard similarity")
plt.show()

# %%
pdg = makeDirectedPath(100)
nums_100_jaccard = []
for i in pdg.nodes():
    nums_100_jaccard.append(calculate_jaccard_similarity(pdg, 0, i))
data['100 node jaccard'] = nums_100_jaccard

# %%
import matplotlib.pyplot as plt
plt.plot(nums_100_jaccard)
plt.ylabel("jaccard similarity")
plt.show()

# %%
pdg = makeDirectedPath(500)
nums_500_jaccard = []
for i in pdg.nodes():
    nums_500_jaccard.append(calculate_jaccard_similarity(pdg, 0, i))
data['500 node jaccard'] = nums_500_jaccard

# %%
import matplotlib.pyplot as plt
plt.plot(nums_500_jaccard)
plt.ylabel("jaccard similarity")
plt.show()

# %%
pdg = makeDirectedPath(1000)
nums_1000_jaccard = []
for i in pdg.nodes():
    nums_1000_jaccard.append(calculate_jaccard_similarity(pdg, 0, i))
data['1000 node jaccard'] = nums_1000_jaccard

# %%
import matplotlib.pyplot as plt
plt.plot(nums_1000_jaccard)
plt.ylabel("jaccard similarity")
plt.show()

# %% [markdown]
# ### Edit distance

# %%
pdg = makeDirectedPath(10)
nums_10_edit = []
for i in pdg.nodes():
    nums_10_edit.append(get_full_similarity(pdg, 0, i))
data["10 node edit"] = nums_10_edit

# %%
import matplotlib.pyplot as plt
plt.plot(nums_10_edit)
plt.ylabel("jaccard similarity")
plt.show()

# %%
pdg = makeDirectedPath(50)
nums_50_edit = []
for i in pdg.nodes():
    nums_50_edit.append(get_full_similarity(pdg, 0, i))
data["50 node edit"] = nums_50_edit

# %%
import matplotlib.pyplot as plt
plt.plot(nums_50_edit)
plt.ylabel("jaccard similarity")
plt.show()

# %%
pdg = makeDirectedPath(100)
nums_100_edit = []
for i in pdg.nodes():
    nums_100_edit.append(get_full_similarity(pdg, 0, i))
data["100 node edit"] = nums_100_edit

# %%
import matplotlib.pyplot as plt
plt.plot(nums_100_edit)
plt.ylabel("jaccard similarity")
plt.show()

# %%
pdg = makeDirectedPath(500)
nums_500_edit = []
for i in pdg.nodes():
    nums_500_edit.append(get_full_similarity(pdg, 0, i))
data["500 node edit"] = nums_500_edit

# %%
import matplotlib.pyplot as plt
plt.plot(nums_500_edit)
plt.ylabel("jaccard similarity")
plt.show()

# %%
pdg = makeDirectedPath(1000)
nums_1000_edit = []
for i in pdg.nodes():
    nums_1000_edit.append(get_full_similarity(pdg, 0, i))
data["1000 node edit"] = nums_1000_edit

# %%
import matplotlib.pyplot as plt
plt.plot(nums_1000_edit)
plt.ylabel("jaccard similarity")
plt.show()

# %% [markdown]
# ### Comparing graphs

# %%
plt.plot(1 - numpy.array(nums_10_edit))
plt.plot(nums_10_jaccard)
plt.ylabel("jaccard similarity")
plt.show()

# %%
plt.plot(1 - numpy.array(nums_50_edit))
plt.plot(nums_50_jaccard)
plt.ylabel("jaccard similarity")
plt.show()

# %%
plt.plot(1 - numpy.array(nums_100_edit))
plt.plot(nums_100_jaccard)
plt.ylabel("jaccard similarity")
plt.show()

# %%
plt.plot(1 - numpy.array(nums_500_edit))
plt.plot(nums_500_jaccard)
plt.ylabel("jaccard similarity")
plt.show()

# %%
plt.plot(1 - numpy.array(nums_1000_edit))
plt.plot(nums_1000_jaccard)
plt.ylabel("jaccard similarity")
plt.show()

# %% [markdown]
# ### Export a file to excel

# %%
import pandas as pd

# %%
dict_df = pd.DataFrame({ key:pd.Series(value) for key, value in data.items() })

# %%
dict_df
# Out:
#      10 node jaccard  50 node jaccard  100 node jaccard  500 node jaccard  \
# 0           1.000000         1.000000          1.000000          1.000000
# 1           0.400190         0.928875          0.958856          0.993708
# 2           0.215011         0.979988          0.967990          0.992124
# 3           0.240002         0.923357          0.942709          0.990985
# 4           0.130253         0.892377          0.952511          0.988203
# 5           0.087853         0.863355          0.945472          0.990955
# 6           0.117234         0.835907          0.925755          0.985920
# 7           0.001820         0.812293          0.915337          0.989355
# 8           0.000833         0.819453          0.913028          0.987883
# 9           0.000000         0.791813          0.878516          0.985899
# 10               NaN         0.788021          0.875110          0.982199
# 11               NaN         0.775395          0.854569          0.985798
# 12               NaN         0.742473          0.824190          0.984873
# 13               NaN         0.716142          0.821740          0.980786
# 14               NaN         0.721964          0.789791          0.983925
# 15               NaN         0.701466          0.813309          0.981430
# 16               NaN         0.701596          0.781800          0.980230
# 17               NaN         0.667016          0.748656          0.974905
# 18               NaN         0.675408          0.733281          0.979565
# 19               NaN         0.650053          0.716473          0.972477
# 20               NaN         0.620707          0.699279          0.967092
# 21               NaN         0.598822          0.660912          0.965237
# 22               NaN         0.598269          0.646330          0.959174
# 23               NaN         0.544020          0.642520          0.963905
# 24               NaN         0.511918          0.640365          0.962778
# 25               NaN         0.457661          0.641422          0.963101
# 26               NaN         0.452231          0.639265          0.960116
# 27               NaN         0.444018          0.620702          0.962202
# 28               NaN         0.434281          0.635511          0.960523
# 29               NaN         0.422340          0.612470          0.960121
# ..               ...              ...               ...               ...
# 970              NaN              NaN               NaN               NaN
# 971              NaN              NaN               NaN               NaN
# 972              NaN              NaN               NaN               NaN
# 973              NaN              NaN               NaN               NaN
# 974              NaN              NaN               NaN               NaN
# 975              NaN              NaN               NaN               NaN
# 976              NaN              NaN               NaN               NaN
# 977              NaN              NaN               NaN               NaN
# 978              NaN              NaN               NaN               NaN
# 979              NaN              NaN               NaN               NaN
# 980              NaN              NaN               NaN               NaN
# 981              NaN              NaN               NaN               NaN
# 982              NaN              NaN               NaN               NaN
# 983              NaN              NaN               NaN               NaN
# 984              NaN              NaN               NaN               NaN
# 985              NaN              NaN               NaN               NaN
# 986              NaN              NaN               NaN               NaN
# 987              NaN              NaN               NaN               NaN
# 988              NaN              NaN               NaN               NaN
# 989              NaN              NaN               NaN               NaN
# 990              NaN              NaN               NaN               NaN
# 991              NaN              NaN               NaN               NaN
# 992              NaN              NaN               NaN               NaN
# 993              NaN              NaN               NaN               NaN
# 994              NaN              NaN               NaN               NaN
# 995              NaN              NaN               NaN               NaN
# 996              NaN              NaN               NaN               NaN
# 997              NaN              NaN               NaN               NaN
# 998              NaN              NaN               NaN               NaN
# 999              NaN              NaN               NaN               NaN
#
#      1000 node jaccard  10 node edit  50 node edit  100 node edit  \
# 0             1.000000      0.000000      0.000000       0.000000
# 1             0.997312      0.117657      0.028131       0.010704
# 2             0.997229      0.279700      0.044245       0.020846
# 3             0.996632      0.381758      0.072885       0.035181
# 4             0.992768      0.447042      0.084773       0.042160
# 5             0.996509      0.563404      0.103520       0.051750
# 6             0.993578      0.676443      0.129615       0.067924
# 7             0.992032      0.800854      0.145274       0.070882
# 8             0.991221      0.901285      0.176772       0.086062
# 9             0.989897      1.000000      0.185518       0.093322
# 10            0.988833           NaN      0.206540       0.102721
# 11            0.988400           NaN      0.227504       0.114030
# 12            0.986296           NaN      0.258119       0.124847
# 13            0.987394           NaN      0.265596       0.131706
# 14            0.985737           NaN      0.297256       0.144470
# 15            0.983784           NaN      0.308072       0.153828
# 16            0.983031           NaN      0.330058       0.166955
# 17            0.982853           NaN      0.348759       0.172716
# 18            0.980550           NaN      0.373580       0.184558
# 19            0.980963           NaN      0.387866       0.191935
# 20            0.980155           NaN      0.413741       0.206985
# 21            0.977729           NaN      0.438217       0.213335
# 22            0.978726           NaN      0.455549       0.228986
# 23            0.975208           NaN      0.470552       0.233319
# 24            0.972249           NaN      0.492331       0.242573
# 25            0.972491           NaN      0.515312       0.258702
# 26            0.970266           NaN      0.530991       0.264529
# 27            0.968720           NaN      0.557169       0.275394
# 28            0.966543           NaN      0.575262       0.285883
# 29            0.967499           NaN      0.592532       0.294934
# ..                 ...           ...           ...            ...
# 970           0.029968           NaN           NaN            NaN
# 971           0.029910           NaN           NaN            NaN
# 972           0.029308           NaN           NaN            NaN
# 973           0.028552           NaN           NaN            NaN
# 974           0.027504           NaN           NaN            NaN
# 975           0.025478           NaN           NaN            NaN
# 976           0.023357           NaN           NaN            NaN
# 977           0.021852           NaN           NaN            NaN
# 978           0.020772           NaN           NaN            NaN
# 979           0.019010           NaN           NaN            NaN
# 980           0.018844           NaN           NaN            NaN
# 981           0.018761           NaN           NaN            NaN
# 982           0.017098           NaN           NaN            NaN
# 983           0.014929           NaN           NaN            NaN
# 984           0.012323           NaN           NaN            NaN
# 985           0.009930           NaN           NaN            NaN
# 986           0.007995           NaN           NaN            NaN
# 987           0.005635           NaN           NaN            NaN
# 988           0.004516           NaN           NaN            NaN
# 989           0.003665           NaN           NaN            NaN
# 990           0.002820           NaN           NaN            NaN
# 991           0.002369           NaN           NaN            NaN
# 992           0.002112           NaN           NaN            NaN
# 993           0.001749           NaN           NaN            NaN
# 994           0.001456           NaN           NaN            NaN
# 995           0.001105           NaN           NaN            NaN
# 996           0.000985           NaN           NaN            NaN
# 997           0.000798           NaN           NaN            NaN
# 998           0.000116           NaN           NaN            NaN
# 999           0.000000           NaN           NaN            NaN
#
#      500 node edit  1000 node edit
# 0         0.000000        0.000000
# 1         0.002610        0.001123
# 2         0.004829        0.002365
# 3         0.006385        0.003156
# 4         0.008017        0.004261
# 5         0.010265        0.005374
# 6         0.012601        0.006138
# 7         0.014177        0.007017
# 8         0.017677        0.008515
# 9         0.018121        0.009389
# 10        0.020402        0.010164
# 11        0.022218        0.011097
# 12        0.024758        0.012447
# 13        0.027182        0.013103
# 14        0.028113        0.014480
# 15        0.030128        0.015077
# 16        0.033166        0.016221
# 17        0.034406        0.017304
# 18        0.036936        0.018418
# 19        0.038169        0.019088
# 20        0.040140        0.020519
# 21        0.042131        0.021253
# 22        0.045026        0.022086
# 23        0.046732        0.023207
# 24        0.048501        0.024448
# 25        0.050221        0.025347
# 26        0.052294        0.026132
# 27        0.055718        0.027539
# 28        0.056203        0.028154
# 29        0.058313        0.029097
# ..             ...             ...
# 970            NaN        0.971083
# 971            NaN        0.972508
# 972            NaN        0.973085
# 973            NaN        0.974231
# 974            NaN        0.975174
# 975            NaN        0.976312
# 976            NaN        0.977129
# 977            NaN        0.978520
# 978            NaN        0.979059
# 979            NaN        0.980161
# 980            NaN        0.981541
# 981            NaN        0.982046
# 982            NaN        0.983417
# 983            NaN        0.984066
# 984            NaN        0.985081
# 985            NaN        0.986718
# 986            NaN        0.987008
# 987            NaN        0.988385
# 988            NaN        0.989328
# 989            NaN        0.990086
# 990            NaN        0.991335
# 991            NaN        0.992404
# 992            NaN        0.993037
# 993            NaN        0.994293
# 994            NaN        0.995301
# 995            NaN        0.996450
# 996            NaN        0.997079
# 997            NaN        0.998037
# 998            NaN        0.999133
# 999            NaN        1.000000
#
# [1000 rows x 10 columns]

# %%
dict_df.to_excel(r'path_tests_file_editandchain.xlsx', index = False, header=True)

# %%
data
# Out:
# {'10 node graph': [0.9999999999999997,
#   0.7662603800125318,
#   0.6131027313549438,
#   0.6551097744683113,
#   0.5189872558130293,
#   0.5162733233818608,
#   0.4077397648381833,
#   0.43987516259647724,
#   0.1995157400308775,
#   0.0],
#  '50 node graph': [1.0,
#   0.991844766692804,
#   0.9380416747962402,
#   0.987460234310881,
#   0.9352364840386042,
#   0.8993857455789868,
#   0.8708676499472607,
#   0.8656306521629512,
#   0.7999411120697629,
#   0.7852001496419003,
#   0.756882196067493,
#   0.7803811275569975,
#   0.7481004493863491,
#   0.7352069866471035,
#   0.7253606059229395,
#   0.6899205145298001,
#   0.6609657856114184,
#   0.07063713424405843,
#   0.07052876055690581,
#   0.07014869590511612,
#   0.06923367195705488,
#   0.06656095506614651,
#   0.06573073931666253,
#   0.06524224008003851,
#   0.06457947227954565,
#   0.06438799484697083,
#   0.06428726847623484,
#   0.06423508748244428,
#   0.06376179426430457,
#   0.06298191331369843,
#   0.06267079420356245,
#   0.06250840076942277,
#   0.06114820151719843,
#   0.057856571830942456,
#   0.053918218291976586,
#   0.051727977735664905,
#   0.050420242092547946,
#   0.049295571453523604,
#   0.04776321990140224,
#   0.04434225419776673,
#   0.04335404055332823,
#   0.04275888396289076,
#   0.04192677866503678,
#   0.040904581359739595,
#   0.037300251920004135,
#   0.035245622293686,
#   0.035112660719123806,
#   0.035188318870344196,
#   0.032646881125867284,
#   0.03052094801736292,
#   0.028397908987682786,
#   0.02783710452152032,
#   0.02752612524333023,
#   0.026944499686708704,
#   0.026292823461187047,
#   0.024110944994462726,
#   0.021116578139979424,
#   0.019876161010755955,
#   0.018494145333977904,
#   0.017774404022338874,
#   0.017555709833465945,
#   0.01686751600564201,
#   0.016304422314972908,
#   0.01602786436665231,
#   0.015479648856548298,
#   0.015083642233466015,
#   0.014471328455300105,
#   0.01419424629079026,
#   0.014009810336681073,
#   0.013678182893613515,
#   0.013489295007666722,
#   0.013361440697292505,
#   0.01327541368382059,
#   0.010478259996811604,
#   0.008145740042439894,
#   0.0070906807781684,
#   0.006735610634067786,
#   0.006504830703201373,
#   0.005915504767994959,
#   0.004579976429348803,
#   0.004500584865519127,
#   0.0044502798986155384,
#   0.004400952522489671,
#   0.0043518264231241395,
#   0.0029407210776171127,
#   0.0023429284490102792,
#   0.0017160410854979108,
#   0.0009760804982213904,
#   0.0]}

# %% [markdown]
# ### Edit distance similarity experiments

# %%
pdg = makeDirectedPath(10)
nums = []
for i in pdg.nodes():
    print(i, get_full_similarity(pdg, 0, i))
    nums.append(get_full_similarity(pdg, 0, i))
data = {"10 node graph": nums}
# Out:
# 0 0.0
# 1 0.17848489918648064
# 2 0.24146792537284373
# 3 0.33799031730877516
# 4 0.5260334570056792
# 5 0.5626236815083989
# 6 0.70464000965503
# 7 0.7931140706146502
# 8 0.9163082052584061
# 9 1.0

# %%
nx.get_edge_attributes(pdg, 'weight')
# Out:
# {(0, 1): 0.17048463210432108,
#  (1, 2): 0.7638942304625188,
#  (2, 3): 0.3396999973450058,
#  (3, 4): 0.0028440874887825096,
#  (4, 5): 0.48206035815725556,
#  (5, 6): 0.5302605219808292,
#  (6, 7): 0.5641200815664781,
#  (7, 8): 0.1441835502236477,
#  (8, 9): 0.28666235496239256}

# %%
import matplotlib.pyplot as plt
plt.plot(nums)
plt.ylabel("jaccard similarity")
plt.show()

# %%
pdg = makeDirectedPath(10)
nums = []
for i in pdg.nodes():
    print(i, get_immediate_similarity(pdg, 0, i))
    nums.append(get_full_similarity(pdg, 0, i))
data = {"10 node graph": nums}
# Out:
# 0 0.0
# 1 1.0
# 2 1.0
# 3 1.0
# 4 1.0
# 5 1.0
# 6 1.0
# 7 1.0
# 8 1.0
# 9 1.0
