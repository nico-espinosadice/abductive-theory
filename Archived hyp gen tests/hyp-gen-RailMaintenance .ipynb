# %%
from similarityfunctions import *
from hypfunctions import *
import networkx as nx
from itertools import permutations, combinations
from collections import Counter
import sys, os

# Disable
def blockPrint():
    sys.stdout = open(os.devnull, 'w')

# Restore
def enablePrint():
    sys.stdout = sys.__stdout__

# %% [markdown]
# # Functionality

# %%
def most_similar_nodes(graph, node1, node2):
    JI, IS, FS = {}, {}, {}
    parents1 = list(graph.predecessors(node1))
    parents2 = list(graph.predecessors(node2))
    for p in parents2: 
        JI[(node1, p)] = calculate_jaccard_similarity(graph, node1, node2)
        IS[(node1, p)] = get_immediate_similarity(graph, node1, node2)
        FS[(node1, p)] = get_full_similarity(graph, node1, node2)
        
    max_JI = max(JI, key=JI.get)
    max_IS = max(IS, key=IS.get)
    max_FS = max(FS, key=FS.get) 
        
    return max_JI, max_IS, max_FS

# %%
def get_all_FBE(graph, observations, bnodes, flipped=False):
    hypotheses = findHypotheses(graph, observations, bnodes)
    not_hyp = bnodes + observations
    possibly_true = []
    for i in range(1, len(not_hyp) + 1):
        possibly_true += [list(x) for x in it.combinations(not_hyp, i)]
    possibly_true

    fbe = {}
    for t in possibly_true:
        false_nodes = list(set(not_hyp) - set(t))
        observeData(graph, t, false_nodes)
        if (flipped == False): fbe[tuple(t)] = findBestExplanation(graph, observations, bnodes)
        elif (flipped==True): fbe[tuple(t)] = findBestExplanation(graph, observations, bnodes, flipped=True)
    
    return fbe

# %%
# get all possible combinations of true/false nodes
def get_possible_truths(graph, bnodes, observations):
    not_hyp = bnodes + observations
    
    possibly_true = []
    for i in range(1, len(not_hyp) + 1):
        possibly_true += [list(x) for x in it.combinations(not_hyp, i)]
    
    true_false_nodes = {}
    for t in possibly_true:
        false_nodes = list(set(not_hyp) - set(t))
        true_false_nodes[tuple(t)] = false_nodes
        
    return true_false_nodes

# %% [markdown]
# ### Rail Maintenance Tests

# %%
# make the graph
rmdg = nx.DiGraph()
rmdg.add_nodes_from(['PeriodicMaintenance', 'TonnageMaintenance', 'RailTraffic', 'PressureMaps', 'WeatherMaps',
                    'Maintained', 'Replaced', 'Damage',
                   'AssetState', 'AssetFailure', 'TestResult'])
rmdg.add_weighted_edges_from([('PeriodicMaintenance','Maintained', .173792),('TonnageMaintenance','Maintained', .36139), 
                             ('RailTraffic','Damage', .105445), ('PressureMaps', 'Damage', .0093638), ('WeatherMaps', 'Damage', .265303),
                             ('Maintained','AssetState', .0119472), ('Replaced','AssetState', .00808351), ('Damage', 'AssetState', 0.561929),
                             ('AssetState','AssetFailure', .530165), ('AssetState', 'TestResult', 0.812023)])

nx.draw_planar(rmdg, with_labels = True)
nx.is_directed_acyclic_graph(rmdg)
# Out:
# C:\Users\hanaa\Anaconda3\lib\site-packages\networkx\drawing\layout.py:950: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   pos = np.row_stack((pos[x] for x in node_list))
# True

# %%
bnodes = [node for node in list(rmdg.nodes()) if not list(rmdg.predecessors(node)) and list(rmdg.successors(node))] #root nodes
observations = [node for node in list(rmdg.nodes()) if not list(rmdg.successors(node)) and list(rmdg.predecessors(node))] #terminal nodes
hypotheses = findHypotheses(rmdg, observations, bnodes)
#is 'Replaced' a bnode or hyp? - a bnode

# %%
# learn the CPTable

# PeriodicMaintenance
cpt_PM = CPT(0)
cpt_PM.add_entry_self((1-.7, .7))
rmdg.nodes['PeriodicMaintenance']['CPT'] = cpt_PM

# TonnageMaintenance
cpt_TM = CPT(0)
cpt_TM.add_entry_self((.5, .5))
rmdg.nodes['TonnageMaintenance']['CPT'] = cpt_TM

# RailTraffic - low (0) or high (1)
cpt_RT = CPT(0)
cpt_RT.add_entry_self((1-.8, .8))
rmdg.nodes['RailTraffic']['CPT'] = cpt_RT

# PressureMaps - low (0) or high (1)
cpt_M = CPT(0)
cpt_M.add_entry_self((1-.6, .6))
rmdg.nodes['PressureMaps']['CPT'] = cpt_M

# WeatherMaps - dry (0) or rain(1)
cpt_B = CPT(0)
cpt_B.add_entry_self((.833333, .166667))
rmdg.nodes['WeatherMaps']['CPT'] = cpt_B

# Damage
cpt_D = CPT(3)
cpt_D.add_entry([1, 1, 1], (1-.75, .75))
cpt_D.add_entry([1, 1, 0], (1-.3, .3))
cpt_D.add_entry([1, 0, 1], (1-.45, .45))
cpt_D.add_entry([1, 0, 0], (1-.1, .1))
cpt_D.add_entry([0, 0, 0], (1-.00999999, .00999999))
cpt_D.add_entry([0, 0, 1], (.5, .5))
cpt_D.add_entry([0, 1, 0], (1-.15, .15))
cpt_D.add_entry([0, 1, 1], (1-.6, .6))
rmdg.nodes['Damage']['CPT'] = cpt_D

# Replaced
cpt_R = CPT(0)
cpt_R.add_entry_self((1-.01, .01))
rmdg.nodes['Replaced']['CPT'] = cpt_R

# Maintained
cpt_M = CPT(2)
cpt_M.add_entry([1, 1], (0, 1))
cpt_M.add_entry([1, 0], (1-.6, .6))
cpt_M.add_entry([0, 1], (1-.4, .4))
cpt_M.add_entry([0, 0], (1-.05, .05))
rmdg.nodes['Maintained']['CPT'] = cpt_M

# AssetState - Poor (0) or Good (1)
cpt_AS = CPT(3)
cpt_AS.add_entry([1, 1, 1], (1-.875, .875))
cpt_AS.add_entry([1, 1, 0], (1-.0714286, 0.0714286))
cpt_AS.add_entry([1, 0, 1], (1-0.125, 0.125))
cpt_AS.add_entry([1, 0, 0], (1-0.0105263, 0.0105263))
cpt_AS.add_entry([0, 0, 0], (1-0.833333, 0.833333))
cpt_AS.add_entry([0, 0, 1], (1-0.967742, 0.967742))
cpt_AS.add_entry([0, 1, 0], (1-0.888889, 0.888889))
cpt_AS.add_entry([0, 1, 1], (1-0.994975, 0.994975))
rmdg.nodes['AssetState']['CPT'] = cpt_AS


# AssetFailure
cpt_AF = CPT(1)
cpt_AF.add_entry([1], (1-.1, .1))
cpt_AF.add_entry([0], (1-.9, .9))
rmdg.nodes['AssetFailure']['CPT'] = cpt_AF

# TestResult
cpt_TR = CPT(1)
cpt_TR.add_entry([1], (1-.95, .95))
cpt_TR.add_entry([0], (1-.01, .01))
rmdg.nodes['TestResult']['CPT'] = cpt_TR

# %%
fbe1 = get_all_FBE(rmdg, observations, bnodes)
fbe2 = get_all_FBE(rmdg, observations, bnodes, flipped=True)
# Out:
# (['Maintained'], 0.5863095891237967)
# (['Damage'], 0.018323235064763747)
# (['AssetState'], 0.7338389005706722)
# (['Maintained', 'Damage'], 0.010844006723303023)
# (['Maintained', 'AssetState'], 0.4517120160725725)
# (['Damage', 'AssetState'], 0.0004023441133479146)
# (['Maintained', 'Damage', 'AssetState'], 0.00036635173097143757)
# (['Maintained'], 0.386464016767189)
# (['Damage'], 0.018240085111399785)
# (['AssetState'], 0.716161219669796)
# (['Maintained', 'Damage'], 0.007147790985989169)
# (['Maintained', 'AssetState'], 0.2977444738952609)
# (['Damage', 'AssetState'], 0.0002948591089192608)
# (['Maintained', 'Damage', 'AssetState'], 0.00024147952570999134)
# (['Maintained'], 0.04761110640092982)
# (['Damage'], 0.24358687269968948)
# (['AssetState'], 0.5300194119525571)
# (['Maintained', 'Damage'], 0.011792115761508999)
# (['Maintained', 'AssetState'], 0.028491715263519683)
# (['Damage', 'AssetState'], 0.0015138512098088826)
# (['Maintained', 'Damage', 'AssetState'], 0.000398382455053341)
# (['Maintained'], 0.047531854566061044)
# (['Damage'], 0.16857819191211573)
# (['AssetState'], 0.5819617820692935)
# (['Maintained', 'Damage'], 0.008160922351281056)
# (['Maintained', 'AssetState'], 0.031154876965080514)
# (['Damage', 'AssetState'], 0.0010476849468328338)
# (['Maintained', 'Damage', 'AssetState'], 0.00027570695094558575)
# (['Maintained'], 0.04803627980739223)
# (['Damage'], 0.6459964368126605)
# (['AssetState'], 0.2513569118498587)
# (['Maintained', 'Damage'], 0.031272887081270614)
# (['Maintained', 'AssetState'], 0.014204279086332755)
# (['Damage', 'AssetState'], 0.004014758581045325)
# (['Maintained', 'Damage', 'AssetState'], 0.001056516895187621)
# (['Maintained'], 0.048123478701541135)
# (['Damage'], 0.019154417933739974)
# (['AssetState'], 0.918111454446782)
# (['Maintained', 'Damage'], 0.0005493162250324435)
# (['Maintained', 'AssetState'], 0.04746934047105483)
# (['Damage', 'AssetState'], 0.0015524154185699497)
# (['Maintained', 'Damage', 'AssetState'], 0.00041795799730729414)
# (['Maintained'], 0.035140187319736026)
# (['Damage'], 0.05581022199221713)
# (['AssetState'], 0.026283157533197255)
# (['Maintained', 'Damage'], 0.0026277697572478615)
# (['Maintained', 'AssetState'], 0.0013980168646974696)
# (['Damage', 'AssetState'], 4.308558593979736e-06)
# (['Maintained', 'Damage', 'AssetState'], 1.1338327963073154e-06)
# (['Maintained'], 0.05318609152647023)
# (['Damage'], 0.00017782096486205424)
# (['AssetState'], 0.9997569051591508)
# (['Maintained', 'Damage'], 4.3784409489694296e-05)
# (['Maintained', 'AssetState'], 0.053177667570758536)
# (['Damage', 'AssetState'], 0.00016388864999090724)
# (['Maintained', 'Damage', 'AssetState'], 4.312865248295965e-05)
# (['Maintained'], 1.0)
# (['Damage'], 0.018495359660599637)
# (['AssetState'], 0.7704325913339198)
# (['Maintained', 'Damage'], 0.018495359660599637)
# (['Maintained', 'AssetState'], 0.7704325913339198)
# (['Damage', 'AssetState'], 0.000624843491846905)
# (['Maintained', 'Damage', 'AssetState'], 0.000624843491846905)
# (['Maintained'], 0.587586430592605)
# (['Damage'], 0.245905132227797)
# (['AssetState'], 0.5688037480429857)
# (['Maintained', 'Damage'], 0.14553090094341)
# (['Maintained', 'AssetState'], 0.3516268899986205)
# (['Damage', 'AssetState'], 0.005399618683283557)
# (['Maintained', 'Damage', 'AssetState'], 0.004916586537693651)
# (['Maintained'], 0.5871624934225556)
# (['Damage'], 0.1703433433959891)
# (['AssetState'], 0.6235987537115995)
# (['Maintained', 'Damage'], 0.10081213031034368)
# (['Maintained', 'AssetState'], 0.38485717437482997)
# (['Damage', 'AssetState'], 0.0037404225411688937)
# (['Maintained', 'Damage', 'AssetState'], 0.0034058166307428337)
# (['Maintained'], 0.5898471927115353)
# (['Damage'], 0.6488592534944881)
# (['AssetState'], 0.27659423712011855)
# (['Maintained', 'Damage'], 0.3840061038622239)
# (['Maintained', 'AssetState'], 0.1744172150124584)
# (['Damage', 'AssetState'], 0.014247740647985604)
# (['Maintained', 'Damage', 'AssetState'], 0.01297318458418224)
# (['Maintained'], 0.5903080409731397)
# (['Damage'], 0.014745923240141132)
# (['AssetState'], 0.9570123382656781)
# (['Maintained', 'Damage'], 0.006738203334898931)
# (['Maintained', 'AssetState'], 0.5822840354817903)
# (['Damage', 'AssetState'], 0.00561516944574911)
# (['Maintained', 'Damage', 'AssetState'], 0.005126893841770927)
# (['Maintained'], 0.5093155923303395)
# (['Damage'], 0.06513263396611425)
# (['AssetState'], 0.03291807243967252)
# (['Maintained', 'Damage'], 0.03808642504500174)
# (['Maintained', 'AssetState'], 0.02026260648676999)
# (['Damage', 'AssetState'], 1.8048092924159406e-05)
# (['Maintained', 'Damage', 'AssetState'], 1.6433569832750786e-05)
# (['Maintained'], 0.6155253903840341)
# (['Damage'], 0.0005611477285049425)
# (['AssetState'], 0.9998072158507574)
# (['Maintained', 'Damage'], 0.0005067192374996293)
# (['Maintained', 'AssetState'], 0.6154278995085213)
# (['Damage', 'AssetState'], 0.0005481673804257259)
# (['Maintained', 'Damage', 'AssetState'], 0.0004991301277157956)
# (['Maintained'], 0.38771352971894324)
# (['Damage'], 0.24504702402154793)
# (['AssetState'], 0.554447651726071)
# (['Maintained', 'Damage'], 0.09602723335704189)
# (['Maintained', 'AssetState'], 0.23201778592464242)
# (['Damage', 'AssetState'], 0.003961294407620524)
# (['Maintained', 'Damage', 'AssetState'], 0.003244164639362647)
# (['Maintained'], 0.38729837442411785)
# (['Damage'], 0.16968958057968436)
# (['AssetState'], 0.6081775821623217)
# (['Maintained', 'Damage'], 0.06649671024427967)
# (['Maintained', 'AssetState'], 0.25385572084483055)
# (['Damage', 'AssetState'], 0.002743107733161727)
# (['Maintained', 'Damage', 'AssetState'], 0.0022465114162597733)
# (['Maintained'], 0.38993237162052596)
# (['Damage'], 0.6478029449722102)
# (['AssetState'], 0.26728228853057034)
# (['Maintained', 'Damage'], 0.25385627438085234)
# (['Maintained', 'AssetState'], 0.11530260572845663)
# (['Damage', 'AssetState'], 0.010472023455109869)
# (['Maintained', 'Damage', 'AssetState'], 0.008576229055403792)
# (['Maintained'], 0.3903856922041639)
# (['Damage'], 0.016371488914654654)
# (['AssetState'], 0.9426682263092647)
# (['Maintained', 'Damage'], 0.00445614491168115)
# (['Maintained', 'AssetState'], 0.3850792136869028)
# (['Damage', 'AssetState'], 0.004117090407531499)
# (['Maintained', 'Damage', 'AssetState'], 0.003390545041496529)
# (['Maintained'], 0.31568714353645133)
# (['Damage'], 0.06132584822723161)
# (['AssetState'], 0.030208720019355567)
# (['Maintained', 'Damage'], 0.023606963758873983)
# (['Maintained', 'AssetState'], 0.012559294195459772)
# (['Damage', 'AssetState'], 1.2437585311594448e-05)
# (['Maintained', 'Damage', 'AssetState'], 1.018595699156029e-05)
# (['Maintained'], 0.4157288879893181)
# (['Damage'], 0.00042495353612726546)
# (['AssetState'], 0.9997893406991603)
# (['Maintained', 'Damage'], 0.00034224067507123297)
# (['Maintained', 'AssetState'], 0.41566304217060907)
# (['Damage', 'AssetState'], 0.00041163495873380743)
# (['Maintained', 'Damage', 'AssetState'], 0.00033711495284993915)
# (['Maintained'], 0.047817420470324765)
# (['Damage'], 0.4388548585936769)
# (['AssetState'], 0.3947993029097186)
# (['Maintained', 'Damage'], 0.021245099285039995)
# (['Maintained', 'AssetState'], 0.021558781420215285)
# (['Damage', 'AssetState'], 0.0027274087115179368)
# (['Maintained', 'Damage', 'AssetState'], 0.0007177401394457768)
# (['Maintained'], 0.04812759568544772)
# (['Damage'], 0.7324232502642607)
# (['AssetState'], 0.19150765860106841)
# (['Maintained', 'Damage'], 0.035456835821300194)
# (['Maintained', 'AssetState'], 0.01113571985884699)
# (['Damage', 'AssetState'], 0.004551886607090213)
# (['Maintained', 'Damage', 'AssetState'], 0.00119786657361522)
# (['Maintained'], 0.043460058803755953)
# (['Damage'], 0.25438474785278464)
# (['AssetState'], 0.7173633839737511)
# (['Maintained', 'Damage'], 0.007295323192785602)
# (['Maintained', 'AssetState'], 0.04131812019555762)
# (['Damage', 'AssetState'], 0.020617217718741924)
# (['Maintained', 'Damage', 'AssetState'], 0.005550789385815134)
# (['Maintained'], 0.040860773377857026)
# (['Damage'], 0.5080367241106991)
# (['AssetState'], 0.013731625299618256)
# (['Maintained', 'Damage'], 0.023920412632932014)
# (['Maintained', 'AssetState'], 0.0007381570359862347)
# (['Damage', 'AssetState'], 3.92205211803263e-05)
# (['Maintained', 'Damage', 'AssetState'], 1.0321204233976544e-05)
# (['Maintained'], 0.05374982377225123)
# (['Damage'], 0.003097567779269596)
# (['AssetState'], 0.9995288115176728)
# (['Maintained', 'Damage'], 0.0007627063331640063)
# (['Maintained', 'AssetState'], 0.053730655242481766)
# (['Damage', 'AssetState'], 0.0028548726073646283)
# (['Maintained', 'Damage', 'AssetState'], 0.0007512833168921778)
# (['Maintained'], 0.04798650203429958)
# (['Damage'], 0.5988837725014208)
# (['AssetState'], 0.2839817150212454)
# (['Maintained', 'Damage'], 0.028992148446901816)
# (['Maintained', 'AssetState'], 0.015877000722479315)
# (['Damage', 'AssetState'], 0.003721961341709607)
# (['Maintained', 'Damage', 'AssetState'], 0.0009794648822264989)
# (['Maintained'], 0.04499760764933729)
# (['Damage'], 0.17682833428931452)
# (['AssetState'], 0.7835508538507575)
# (['Maintained', 'Damage'], 0.005071136768895558)
# (['Maintained', 'AssetState'], 0.043346202984756825)
# (['Damage', 'AssetState'], 0.014331473477313537)
# (['Maintained', 'Damage', 'AssetState'], 0.003858473628507491)
# (['Maintained'], 0.039418395571534925)
# (['Damage'], 0.39401318465875873)
# (['AssetState'], 0.016896345023281946)
# (['Maintained', 'Damage'], 0.018551725716976886)
# (['Maintained', 'AssetState'], 0.0009045328517762033)
# (['Damage', 'AssetState'], 3.0417884615107935e-05)
# (['Maintained', 'Damage', 'AssetState'], 8.004717684260255e-06)
# (['Maintained'], 0.0535287506611952)
# (['Damage'], 0.0019525605234529016)
# (['AssetState'], 0.9996182606689517)
# (['Maintained', 'Damage'], 0.00048077407283553107)
# (['Maintained', 'AssetState'], 0.05351379572117814)
# (['Damage', 'AssetState'], 0.0017995769422490722)
# (['Maintained', 'Damage', 'AssetState'], 0.0004735735425419238)
# (['Maintained'], 0.0354368245454727)
# (['Damage'], 0.6590894673420378)
# (['AssetState'], 0.37198406330214795)
# (['Maintained', 'Damage'], 0.018901568265420055)
# (['Maintained', 'AssetState'], 0.03073518271054685)
# (['Damage', 'AssetState'], 0.05341747553270886)
# (['Maintained', 'Damage', 'AssetState'], 0.014381628028037)
# (['Maintained'], 0.045237820266272724)
# (['Damage'], 0.8540531258999552)
# (['AssetState'], 0.00412795103448861)
# (['Maintained', 'Damage'], 0.04021225673741038)
# (['Maintained', 'AssetState'], 0.0002332721551879029)
# (['Damage', 'AssetState'], 6.593304602559472e-05)
# (['Maintained', 'Damage', 'AssetState'], 1.7350825876829332e-05)
# (['Maintained'], 0.05649250299414019)
# (['Damage'], 0.017302767111016353)
# (['AssetState'], 0.9984190866512864)
# (['Maintained', 'Damage'], 0.004260416880997475)
# (['Maintained', 'AssetState'], 0.056421059789226936)
# (['Damage', 'AssetState'], 0.015947091194400922)
# (['Maintained', 'Damage', 'AssetState'], 0.0041966088211449785)
# (['Maintained'], 0.01330332729353886)
# (['Damage'], 0.18902116390046977)
# (['AssetState'], 0.12158671492733375)
# (['Maintained', 'Damage'], 0.00146442218945011)
# (['Maintained', 'AssetState'], 0.0062864275787959285)
# (['Damage', 'AssetState'], 0.00020558842832452972)
# (['Maintained', 'Damage', 'AssetState'], 5.535073070275801e-05)
# (['Maintained'], 0.051701171152207834)
# (['Damage'], 0.0017009908207027565)
# (['AssetState'], 0.9999525847151897)
# (['Maintained', 'Damage'], 0.0004552911399001387)
# (['Maintained', 'AssetState'], 0.05170079239165843)
# (['Damage', 'AssetState'], 0.0016907988706949687)
# (['Maintained', 'Damage', 'AssetState'], 0.00045521508057172233)
# (['Maintained'], 0.0528325425025018)
# (['Damage'], 0.001267751447641754)
# (['AssetState'], 0.9806849490305343)
# (['Maintained', 'Damage'], 9.440894385399202e-05)
# (['Maintained', 'AssetState'], 0.0521632188205694)
# (['Damage', 'AssetState'], 0.00016076221282755788)
# (['Maintained', 'Damage', 'AssetState'], 4.230590470917917e-05)
# (['Maintained'], 1.0)
# (['Damage'], 0.2476757347793687)
# (['AssetState'], 0.5984258173627163)
# (['Maintained', 'Damage'], 0.2476757347793687)
# (['Maintained', 'AssetState'], 0.5984258173627163)
# (['Damage', 'AssetState'], 0.008367426954933371)
# (['Maintained', 'Damage', 'AssetState'], 0.008367426954933371)
# (['Maintained'], 1.0)
# (['Damage'], 0.1716937499238282)
# (['AssetState'], 0.6554525854189137)
# (['Maintained', 'Damage'], 0.1716937499238282)
# (['Maintained', 'AssetState'], 0.6554525854189137)
# (['Damage', 'AssetState'], 0.005800466938701097)
# (['Maintained', 'Damage', 'AssetState'], 0.005800466938701097)
# (['Maintained'], 1.0)
# (['Damage'], 0.6510264160060554)
# (['AssetState'], 0.29569898300381875)
# (['Maintained', 'Damage'], 0.6510264160060554)
# (['Maintained', 'AssetState'], 0.29569898300381875)
# (['Damage', 'AssetState'], 0.021994144830196346)
# (['Maintained', 'Damage', 'AssetState'], 0.021994144830196346)
# (['Maintained'], 1.0)
# (['Damage'], 0.01141472395292263)
# (['AssetState'], 0.9864070875976522)
# (['Maintained', 'Damage'], 0.01141472395292263)
# (['Maintained', 'AssetState'], 0.9864070875976522)
# (['Damage', 'AssetState'], 0.008685116051136785)
# (['Maintained', 'Damage', 'AssetState'], 0.008685116051136785)
# (['Maintained'], 1.0)
# (['Damage'], 0.07477961723249008)
# (['AssetState'], 0.03978399010731204)
# (['Maintained', 'Damage'], 0.07477961723249008)
# (['Maintained', 'AssetState'], 0.03978399010731204)
# (['Damage', 'AssetState'], 3.226598611984385e-05)
# (['Maintained', 'Damage', 'AssetState'], 3.226598611984385e-05)
# (['Maintained'], 1.0)
# (['Damage'], 0.0008232304392569095)
# (['AssetState'], 0.9998416135596746)
# (['Maintained', 'Damage'], 0.0008232304392569095)
# (['Maintained', 'AssetState'], 0.9998416135596746)
# (['Damage', 'AssetState'], 0.0008109009563429737)
# (['Maintained', 'Damage', 'AssetState'], 0.0008109009563429737)
# (['Maintained'], 0.5886863104831241)
# (['Damage'], 0.441945720077329)
# (['AssetState'], 0.42664134971220985)
# (['Maintained', 'Damage'], 0.2615511039897989)
# (['Maintained', 'AssetState'], 0.2654128844247225)
# (['Damage', 'AssetState'], 0.009704304849221848)
# (['Maintained', 'Damage', 'AssetState'], 0.00883618962336526)
# (['Maintained'], 0.5903297758166629)
# (['Damage'], 0.7348739869494597)
# (['AssetState'], 0.21421908851504165)
# (['Maintained', 'Damage'], 0.4349111075142554)
# (['Maintained', 'AssetState'], 0.13658997326180583)
# (['Damage', 'AssetState'], 0.01613646398447488)
# (['Maintained', 'Damage', 'AssetState'], 0.014692948936868728)
# (['Maintained'], 0.5642488046185667)
# (['Damage'], 0.20727777166244787)
# (['AssetState'], 0.8444116911603592)
# (['Maintained', 'Damage'], 0.09471633274641662)
# (['Maintained', 'AssetState'], 0.5364396775140765)
# (['Damage', 'AssetState'], 0.07893027728868053)
# (['Maintained', 'Damage', 'AssetState'], 0.07206677491575178)
# (['Maintained'], 0.548357958633294)
# (['Damage'], 0.5489776544719588)
# (['AssetState'], 0.016024581724945815)
# (['Maintained', 'Damage'], 0.3210156724093943)
# (['Maintained', 'AssetState'], 0.00990618267699179)
# (['Damage', 'AssetState'], 0.00015212035991591706)
# (['Maintained', 'Damage', 'AssetState'], 0.00013851217234786258)
# (['Maintained'], 0.6181580724401758)
# (['Damage'], 0.00971381145703534)
# (['AssetState'], 0.9995971450175722)
# (['Maintained', 'Damage'], 0.008771620884643316)
# (['Maintained', 'AssetState'], 0.6179376218306256)
# (['Damage', 'AssetState'], 0.009489113668051791)
# (['Maintained', 'Damage', 'AssetState'], 0.008640248738197475)
# (['Maintained'], 0.5895836887667121)
# (['Damage'], 0.6018927904387239)
# (['AssetState'], 0.31065282214255274)
# (['Maintained', 'Damage'], 0.3562105405052989)
# (['Maintained', 'AssetState'], 0.19507195264660507)
# (['Damage', 'AssetState'], 0.013216444598545186)
# (['Maintained', 'Damage', 'AssetState'], 0.012034144890740034)
# (['Maintained'], 0.5731707381919486)
# (['Damage'], 0.14136040021641955)
# (['AssetState'], 0.8829629165348959)
# (['Maintained', 'Damage'], 0.06459514976776788)
# (['Maintained', 'AssetState'], 0.5521354680943137)
# (['Damage', 'AssetState'], 0.05382929147313992)
# (['Maintained', 'Damage', 'AssetState'], 0.04914848351895384)
# (['Maintained'], 0.539069628128781)
# (['Damage'], 0.4338690458249188)
# (['AssetState'], 0.020043608745893306)
# (['Maintained', 'Damage'], 0.25370570614039967)
# (['Maintained', 'AssetState'], 0.012370016104597042)
# (['Damage', 'AssetState'], 0.00012022404713493381)
# (['Maintained', 'Damage', 'AssetState'], 0.00010946919890484085)
# (['Maintained'], 0.6171295759441159)
# (['Damage'], 0.006138186913825563)
# (['AssetState'], 0.9996792123205158)
# (['Maintained', 'Damage'], 0.005542813834229924)
# (['Maintained', 'AssetState'], 0.6169571613878821)
# (['Damage', 'AssetState'], 0.005996199699640402)
# (['Maintained', 'Damage', 'AssetState'], 0.005459799376545447)
# (['Maintained'], 0.5114930445031032)
# (['Damage'], 0.5970498997383196)
# (['AssetState'], 0.6164567101813506)
# (['Maintained', 'Damage'], 0.27282412637049047)
# (['Maintained', 'AssetState'], 0.44362982235622445)
# (['Damage', 'AssetState'], 0.22735343864207547)
# (['Maintained', 'Damage', 'AssetState'], 0.20758357441232977)
# (['Maintained'], 0.5745342528007668)
# (['Damage'], 0.8733757580589735)
# (['AssetState'], 0.004698193897097965)
# (['Maintained', 'Damage'], 0.5107080478695271)
# (['Maintained', 'AssetState'], 0.002962628229902307)
# (['Damage', 'AssetState'], 0.00024201027778727964)
# (['Maintained', 'Damage', 'AssetState'], 0.00022036083352257622)
# (['Maintained'], 0.6305105535855723)
# (['Damage'], 0.05265789043271982)
# (['AssetState'], 0.9986114977002059)
# (['Maintained', 'Damage'], 0.04755034143949457)
# (['Maintained', 'AssetState'], 0.6297131788492385)
# (['Damage', 'AssetState'], 0.05143981948239264)
# (['Maintained', 'Damage', 'AssetState'], 0.04683818225007093)
# (['Maintained'], 0.27759064848079895)
# (['Damage'], 0.16787656109019153)
# (['AssetState'], 0.21559124775520064)
# (['Maintained', 'Damage'], 0.030557010005802132)
# (['Maintained', 'AssetState'], 0.13117421451948152)
# (['Damage', 'AssetState'], 0.001264959017518808)
# (['Maintained', 'Damage', 'AssetState'], 0.0011549625812128247)
# (['Maintained'], 0.6084293516444781)
# (['Damage'], 0.005872327052653976)
# (['AssetState'], 0.9999761203960623)
# (['Maintained', 'Damage'], 0.005357953928033741)
# (['Maintained', 'AssetState'], 0.6084248943172963)
# (['Damage', 'AssetState'], 0.005867254927875237)
# (['Maintained', 'Damage', 'AssetState'], 0.005357058847190435)
# (['Maintained'], 0.613857303779809)
# (['Damage'], 0.0015752804467821467)
# (['AssetState'], 0.9846216599279469)
# (['Maintained', 'Damage'], 0.0010969303573487234)
# (['Maintained', 'AssetState'], 0.6060804826902779)
# (['Damage', 'AssetState'], 0.0005398415489268684)
# (['Maintained', 'Damage', 'AssetState'], 0.000491549097746195)
# (['Maintained'], 0.3887919805268065)
# (['Damage'], 0.4408033994582826)
# (['AssetState'], 0.41487316572612204)
# (['Maintained', 'Damage'], 0.17273880828944768)
# (['Maintained', 'AssetState'], 0.17528928251811013)
# (['Damage', 'AssetState'], 0.007125783502600971)
# (['Maintained', 'Damage', 'AssetState'], 0.00583577297926156)
# (['Maintained'], 0.3904070805513639)
# (['Damage'], 0.7339703426974727)
# (['AssetState'], 0.20584485018086227)
# (['Maintained', 'Damage'], 0.2876229232196696)
# (['Maintained', 'AssetState'], 0.0903320396128751)
# (['Damage', 'AssetState'], 0.011864957860623322)
# (['Maintained', 'Damage', 'AssetState'], 0.009716994693682316)
# (['Maintained'], 0.36528311312336814)
# (['Damage'], 0.22527484277291124)
# (['AssetState'], 0.795873287641043)
# (['Maintained', 'Damage'], 0.061317412825762876)
# (['Maintained', 'AssetState'], 0.3472800541202771)
# (['Damage', 'AssetState'], 0.056651957502063546)
# (['Maintained', 'Damage', 'AssetState'], 0.0466545532369935)
# (['Maintained'], 0.35048867999641514)
# (['Damage'], 0.5330150982397943)
# (['AssetState'], 0.015130575517606958)
# (['Maintained', 'Damage'], 0.20518049844913658)
# (['Maintained', 'AssetState'], 0.006331639462142023)
# (['Damage', 'AssetState'], 0.00010810157459479797)
# (['Maintained', 'Damage', 'AssetState'], 8.853149240440467e-05)
# (['Maintained'], 0.4184370569532938)
# (['Damage'], 0.00737259318258468)
# (['AssetState'], 0.9995729645843063)
# (['Maintained', 'Damage'], 0.005937593297441584)
# (['Maintained', 'AssetState'], 0.4182878318466806)
# (['Damage', 'AssetState'], 0.007141526855221944)
# (['Maintained', 'Damage', 'AssetState'], 0.005848666246618747)
# (['Maintained'], 0.38967332696697565)
# (['Damage'], 0.6007821239152558)
# (['AssetState'], 0.30080817965763085)
# (['Maintained', 'Damage'], 0.23543009934646858)
# (['Maintained', 'AssetState'], 0.1289288327239061)
# (['Damage', 'AssetState'], 0.009711910916553757)
# (['Maintained', 'Damage', 'AssetState'], 0.007953722882982957)
# (['Maintained'], 0.3737574614725004)
# (['Damage'], 0.1547514202114716)
# (['AssetState'], 0.8454296078167541)
# (['Maintained', 'Damage'], 0.042121688341584)
# (['Maintained', 'AssetState'], 0.36004062523295133)
# (['Damage', 'AssetState'], 0.03891677727211567)
# (['Maintained', 'Damage', 'AssetState'], 0.03204911069468349)
# (['Maintained'], 0.3420138907932259)
# (['Damage'], 0.4181504293230744)
# (['AssetState'], 0.01880237019180334)
# (['Maintained', 'Damage'], 0.16096413365880036)
# (['Maintained', 'AssetState'], 0.007848183455992072)
# (['Damage', 'AssetState'], 8.480570245869321e-05)
# (['Maintained', 'Damage', 'AssetState'], 6.945296986851933e-05)
# (['Maintained'], 0.4173776355506951)
# (['Damage'], 0.00465471322867057)
# (['AssetState'], 0.999657609778213)
# (['Maintained', 'Damage'], 0.003748720888784725)
# (['Maintained', 'AssetState'], 0.41726102798136044)
# (['Damage', 'AssetState'], 0.004508828671630819)
# (['Maintained', 'Damage', 'AssetState'], 0.003692576475333364)
# (['Maintained'], 0.3175725469364517)
# (['Damage'], 0.6223215868083967)
# (['AssetState'], 0.5168712928781786)
# (['Maintained', 'Damage'], 0.1693893076519897)
# (['Maintained', 'AssetState'], 0.27543806137089527)
# (['Damage', 'AssetState'], 0.1565009907654253)
# (['Maintained', 'Damage', 'AssetState'], 0.12888316886564435)
# (['Maintained'], 0.3750634428510782)
# (['Damage'], 0.8660938251945042)
# (['AssetState'], 0.004483292003412324)
# (['Maintained', 'Damage'], 0.3333968650118443)
# (['Maintained', 'AssetState'], 0.0019340422931760008)
# (['Damage', 'AssetState'], 0.0001756537602021863)
# (['Maintained', 'Damage', 'AssetState'], 0.0001438544220603176)
# (['Maintained'], 0.43130653672415653)
# (['Damage'], 0.04038844598744931)
# (['AssetState'], 0.9985447244449158)
# (['Maintained', 'Damage'], 0.032527247909952886)
# (['Maintained', 'AssetState'], 0.43076108521023077)
# (['Damage', 'AssetState'], 0.03912262137851078)
# (['Maintained', 'Damage', 'AssetState'], 0.032040088873772056)
# (['Maintained'], 0.14586912420305)
# (['Damage'], 0.178415089007102)
# (['AssetState'], 0.16873913128787005)
# (['Maintained', 'Damage'], 0.016057184606917716)
# (['Maintained', 'AssetState'], 0.06892979966975836)
# (['Damage', 'AssetState'], 0.0007369658161922287)
# (['Maintained', 'Damage', 'AssetState'], 0.0006069130250994825)
# (['Maintained'], 0.40848898215756957)
# (['Damage'], 0.004374255755575033)
# (['AssetState'], 0.9999676679180044)
# (['Maintained', 'Damage'], 0.003597237938298138)
# (['Maintained', 'AssetState'], 0.40848598958490906)
# (['Damage', 'AssetState'], 0.004367344924253545)
# (['Maintained', 'Damage', 'AssetState'], 0.003596636996444095)
# (['Maintained'], 0.41401919397114745)
# (['Damage'], 0.001465738019885255)
# (['AssetState'], 0.9832193958588692)
# (['Maintained', 'Damage'], 0.0007398302823727665)
# (['Maintained', 'AssetState'], 0.40877407726516407)
# (['Damage', 'AssetState'], 0.0004048127530121652)
# (['Maintained', 'Damage', 'AssetState'], 0.0003315277996906001)
# (['Maintained'], 0.048247119457671864)
# (['Damage'], 0.8455477033716078)
# (['AssetState'], 0.11317069612073846)
# (['Maintained', 'Damage'], 0.04093322554507587)
# (['Maintained', 'AssetState'], 0.007119268591310395)
# (['Damage', 'AssetState'], 0.00525493594754732)
# (['Maintained', 'Damage', 'AssetState'], 0.0013828798169644746)
# (['Maintained'], 0.039520082901862055)
# (['Damage'], 0.4531234099483331)
# (['AssetState'], 0.5477576917239316)
# (['Maintained', 'Damage'], 0.012994811008493356)
# (['Maintained', 'AssetState'], 0.03612114883464488)
# (['Damage', 'AssetState'], 0.03672446589356819)
# (['Maintained', 'Damage', 'AssetState'], 0.00988735620211451)
# (['Maintained'], 0.04347794479186625)
# (['Damage'], 0.7149306091037729)
# (['AssetState'], 0.007989292078862911)
# (['Maintained', 'Damage'], 0.033661809003298224)
# (['Maintained', 'AssetState'], 0.00043627078457595466)
# (['Damage', 'AssetState'], 5.519276415676659e-05)
# (['Maintained', 'Damage', 'AssetState'], 1.4524431954398337e-05)
# (['Maintained'], 0.05459780368034391)
# (['Damage'], 0.00748952274346578)
# (['AssetState'], 0.9991857074526053)
# (['Maintained', 'Damage'], 0.0018441263713571338)
# (['Maintained', 'AssetState'], 0.054562472898033135)
# (['Damage', 'AssetState'], 0.006902716855996161)
# (['Maintained', 'Damage', 'AssetState'], 0.001816506978897217)
# (['Maintained'], 0.03376163850782449)
# (['Damage'], 0.7435885201721112)
# (['AssetState'], 0.29987167108523516)
# (['Maintained', 'Damage'], 0.021324857810422163)
# (['Maintained', 'AssetState'], 0.028525551464408053)
# (['Damage', 'AssetState'], 0.06026590250771481)
# (['Maintained', 'Damage', 'AssetState'], 0.016225435290538607)
# (['Maintained'], 0.04579028192712659)
# (['Damage'], 0.89772658905638)
# (['AssetState'], 0.002915795448754561)
# (['Maintained', 'Damage'], 0.042268579066548156)
# (['Maintained', 'AssetState'], 0.0001695466464381425)
# (['Damage', 'AssetState'], 6.930464478106483e-05)
# (['Maintained', 'Damage', 'AssetState'], 1.8238089949385407e-05)
# (['Maintained'], 0.058119893939958894)
# (['Damage'], 0.025731537268144953)
# (['AssetState'], 0.9977606224074576)
# (['Maintained', 'Damage'], 0.006335811783620604)
# (['Maintained', 'AssetState'], 0.05801743313286101)
# (['Damage', 'AssetState'], 0.023715465205907768)
# (['Maintained', 'Damage', 'AssetState'], 0.00624092063357691)
# (['Maintained'], 0.009098123368760421)
# (['Damage'], 0.8028395211427407)
# (['AssetState'], 0.03038268318043728)
# (['Maintained', 'Damage'], 0.006219917310148405)
# (['Maintained', 'AssetState'], 0.001749957390575135)
# (['Damage', 'AssetState'], 0.0008732065338221311)
# (['Maintained', 'Damage', 'AssetState'], 0.00023509406679826615)
# (['Maintained'], 0.05758672234424348)
# (['Damage'], 0.028907458772296377)
# (['AssetState'], 0.9997905841899465)
# (['Maintained', 'Damage'], 0.007737437319395733)
# (['Maintained', 'AssetState'], 0.057585135303558424)
# (['Damage', 'AssetState'], 0.02873425185602524)
# (['Maintained', 'Damage', 'AssetState'], 0.0077361447304683355)
# (['Maintained'], 0.05327509717896108)
# (['Damage'], 0.02169537275086673)
# (['AssetState'], 0.9632201521852624)
# (['Maintained', 'Damage'], 0.001615645741709147)
# (['Maintained', 'AssetState'], 0.05177884751625501)
# (['Damage', 'AssetState'], 0.0027511671456072603)
# (['Maintained', 'Damage', 'AssetState'], 0.0007239923676960833)
# (['Maintained'], 0.03635699638473678)
# (['Damage'], 0.6126745336503263)
# (['AssetState'], 0.41159506237251203)
# (['Maintained', 'Damage'], 0.0175704666757575)
# (['Maintained', 'AssetState'], 0.031948922798011634)
# (['Damage', 'AssetState'], 0.049655666692358165)
# (['Maintained', 'Damage', 'AssetState'], 0.013368833340250274)
# (['Maintained'], 0.04489843736482591)
# (['Damage'], 0.8272240666321141)
# (['AssetState'], 0.00487259072415607)
# (['Maintained', 'Damage'], 0.03894903670274945)
# (['Maintained', 'AssetState'], 0.00027241939306544514)
# (['Damage', 'AssetState'], 6.386183810434746e-05)
# (['Maintained', 'Damage', 'AssetState'], 1.6805770397634263e-05)
# (['Maintained'], 0.055893721022653976)
# (['Damage'], 0.014201486730381744)
# (['AssetState'], 0.9986613618827461)
# (['Maintained', 'Damage'], 0.0034967964033254585)
# (['Maintained', 'AssetState'], 0.05583369042946418)
# (['Damage', 'AssetState'], 0.013088796868870843)
# (['Maintained', 'Damage', 'AssetState'], 0.003444425050843364)
# (['Maintained'], 0.009669722719795807)
# (['Damage'], 0.7194052380664985)
# (['AssetState'], 0.042779743178207395)
# (['Maintained', 'Damage'], 0.00557351871130131)
# (['Maintained', 'AssetState'], 0.0023665846604916585)
# (['Damage', 'AssetState'], 0.0007824594303122796)
# (['Maintained', 'Damage', 'AssetState'], 0.0002106621543148445)
# (['Maintained'], 0.05531321387395788)
# (['Damage'], 0.018397969802392767)
# (['AssetState'], 0.9998531627920713)
# (['Maintained', 'Damage'], 0.0049244431781936635)
# (['Maintained', 'AssetState'], 0.05531209357547474)
# (['Damage', 'AssetState'], 0.018287733353031264)
# (['Maintained', 'Damage', 'AssetState'], 0.004923620518123802)
# (['Maintained'], 0.05310341295551812)
# (['Damage'], 0.013770701547999342)
# (['AssetState'], 0.9699954281985202)
# (['Maintained', 'Damage'], 0.0010254986430451563)
# (['Maintained', 'AssetState'], 0.051927960139858814)
# (['Damage', 'AssetState'], 0.0017462480182233937)
# (['Maintained', 'Damage', 'AssetState'], 0.0004595395955192272)
# (['Maintained'], 0.00803196586843256)
# (['Damage'], 0.958462662640511)
# (['AssetState'], 0.007259461513555247)
# (['Maintained', 'Damage'], 0.007425591727227281)
# (['Maintained', 'AssetState'], 0.0005998129974134706)
# (['Damage', 'AssetState'], 0.0010424696809282366)
# (['Maintained', 'Damage', 'AssetState'], 0.00028066491409606373)
# (['Maintained'], 0.08255761869399116)
# (['Damage'], 0.144337580624147)
# (['AssetState'], 0.999103257176306)
# (['Maintained', 'Damage'], 0.038633730889650504)
# (['Maintained', 'AssetState'], 0.08255090522809215)
# (['Damage', 'AssetState'], 0.14347274267907298)
# (['Maintained', 'Damage', 'AssetState'], 0.03862727687513503)
# (['Maintained'], 0.05522365439533518)
# (['Damage'], 0.11163768049512042)
# (['AssetState'], 0.8863230867251578)
# (['Maintained', 'Damage'], 0.008313613468522768)
# (['Maintained', 'AssetState'], 0.05008647023808164)
# (['Damage', 'AssetState'], 0.01415665553742126)
# (['Maintained', 'Damage', 'AssetState'], 0.0037254408833575867)
# (['Maintained'], 0.05153598452542009)
# (['Damage'], 0.002506837826962693)
# (['AssetState'], 0.9961738752738521)
# (['Maintained', 'Damage'], 0.0004596323980883719)
# (['Maintained', 'AssetState'], 0.05150542085572644)
# (['Damage', 'AssetState'], 0.0016844095300864663)
# (['Maintained', 'Damage', 'AssetState'], 0.000453494873484818)
# (['Maintained'], 1.0)
# (['Damage'], 0.44429622250795786)
# (['AssetState'], 0.4508562195151149)
# (['Maintained', 'Damage'], 0.44429622250795786)
# (['Maintained', 'AssetState'], 0.4508562195151149)
# (['Damage', 'AssetState'], 0.015010013764569388)
# (['Maintained', 'Damage', 'AssetState'], 0.015010013764569388)
# (['Maintained'], 1.0)
# (['Damage'], 0.7367256833904384)
# (['AssetState'], 0.23137910174503246)
# (['Maintained', 'Damage'], 0.7367256833904384)
# (['Maintained', 'AssetState'], 0.23137910174503246)
# (['Damage', 'AssetState'], 0.024889391554987178)
# (['Maintained', 'Damage', 'AssetState'], 0.024889391554987178)
# (['Maintained'], 1.0)
# (['Damage'], 0.16786270873971113)
# (['AssetState'], 0.950714778876157)
# (['Maintained', 'Damage'], 0.16786270873971113)
# (['Maintained', 'AssetState'], 0.950714778876157)
# (['Damage', 'AssetState'], 0.12772162621499764)
# (['Maintained', 'Damage', 'AssetState'], 0.12772162621499764)
# (['Maintained'], 1.0)
# (['Damage'], 0.5854126257408232)
# (['AssetState'], 0.018065175349477137)
# (['Maintained', 'Damage'], 0.5854126257408232)
# (['Maintained', 'AssetState'], 0.018065175349477137)
# (['Damage', 'AssetState'], 0.00025259444158170867)
# (['Maintained', 'Damage', 'AssetState'], 0.00025259444158170867)
# (['Maintained'], 1.0)
# (['Damage'], 0.014189931792069602)
# (['AssetState'], 0.999643375021085)
# (['Maintained', 'Damage'], 0.014189931792069602)
# (['Maintained', 'AssetState'], 0.999643375021085)
# (['Damage', 'AssetState'], 0.013977409862319094)
# (['Maintained', 'Damage', 'AssetState'], 0.013977409862319094)
# (['Maintained'], 1.0)
# (['Damage'], 0.6041729906918188)
# (['AssetState'], 0.3308638898315785)
# (['Maintained', 'Damage'], 0.6041729906918188)
# (['Maintained', 'AssetState'], 0.3308638898315785)
# (['Damage', 'AssetState'], 0.02041125818102769)
# (['Maintained', 'Damage', 'AssetState'], 0.02041125818102769)
# (['Maintained'], 1.0)
# (['Damage'], 0.11269791959640425)
# (['AssetState'], 0.9633001674789083)
# (['Maintained', 'Damage'], 0.11269791959640425)
# (['Maintained', 'AssetState'], 0.9633001674789083)
# (['Damage', 'AssetState'], 0.08574841708422065)
# (['Maintained', 'Damage', 'AssetState'], 0.08574841708422065)
# (['Maintained'], 1.0)
# (['Damage'], 0.4706362460468477)
# (['AssetState'], 0.02294697281970021)
# (['Maintained', 'Damage'], 0.4706362460468477)
# (['Maintained', 'AssetState'], 0.02294697281970021)
# (['Damage', 'AssetState'], 0.00020307061127674807)
# (['Maintained', 'Damage', 'AssetState'], 0.00020307061127674807)
# (['Maintained'], 1.0)
# (['Damage'], 0.008981604593735846)
# (['AssetState'], 0.9997206185492408)
# (['Maintained', 'Damage'], 0.008981604593735846)
# (['Maintained', 'AssetState'], 0.9997206185492408)
# (['Damage', 'AssetState'], 0.008847087531322372)
# (['Maintained', 'Damage', 'AssetState'], 0.008847087531322372)
# (['Maintained'], 1.0)
# (['Damage'], 0.533387754344791)
# (['AssetState'], 0.8673232747225226)
# (['Maintained', 'Damage'], 0.533387754344791)
# (['Maintained', 'AssetState'], 0.8673232747225226)
# (['Damage', 'AssetState'], 0.405838508740602)
# (['Maintained', 'Damage', 'AssetState'], 0.405838508740602)
# (['Maintained'], 1.0)
# (['Damage'], 0.888907920424071)
# (['AssetState'], 0.005156573721166224)
# (['Maintained', 'Damage'], 0.888907920424071)
# (['Maintained', 'AssetState'], 0.005156573721166224)
# (['Damage', 'AssetState'], 0.00038354690333666043)
# (['Maintained', 'Damage', 'AssetState'], 0.00038354690333666043)
# (['Maintained'], 1.0)
# (['Damage'], 0.07541561543908572)
# (['AssetState'], 0.9987353506903267)
# (['Maintained', 'Damage'], 0.07541561543908572)
# (['Maintained', 'AssetState'], 0.9987353506903267)
# (['Damage', 'AssetState'], 0.0742861193737562)
# (['Maintained', 'Damage', 'AssetState'], 0.0742861193737562)
# (['Maintained'], 1.0)
# (['Damage'], 0.11007939270661626)
# (['AssetState'], 0.4725455098627176)
# (['Maintained', 'Damage'], 0.11007939270661626)
# (['Maintained', 'AssetState'], 0.4725455098627176)
# (['Damage', 'AssetState'], 0.0041606681908548295)
# (['Maintained', 'Damage', 'AssetState'], 0.0041606681908548295)
# (['Maintained'], 1.0)
# (['Damage'], 0.00880620554145215)
# (['AssetState'], 0.9999926740431413)
# (['Maintained', 'Damage'], 0.00880620554145215)
# (['Maintained', 'AssetState'], 0.9999926740431413)
# (['Damage', 'AssetState'], 0.008804734407883581)
# (['Maintained', 'Damage', 'AssetState'], 0.008804734407883581)
# (['Maintained'], 1.0)
# (['Damage'], 0.0017869468206933524)
# (['AssetState'], 0.9873312233288659)
# (['Maintained', 'Damage'], 0.0017869468206933524)
# (['Maintained', 'AssetState'], 0.9873312233288659)
# (['Damage', 'AssetState'], 0.0008007546619051287)
# (['Maintained', 'Damage', 'AssetState'], 0.0008007546619051287)
# (['Maintained'], 0.5909598570520186)
# (['Damage'], 0.8471785184140501)
# (['AssetState'], 0.13277941466202128)
# (['Maintained', 'Damage'], 0.5013748673227701)
# (['Maintained', 'AssetState'], 0.08720110125386399)
# (['Damage', 'AssetState'], 0.018602462318140646)
# (['Maintained', 'Damage', 'AssetState'], 0.016938347162267706)
# (['Maintained'], 0.5397360227200656)
# (['Damage'], 0.3883840460242878)
# (['AssetState'], 0.7384931958304517)
# (['Maintained', 'Damage'], 0.1774735044746746)
# (['Maintained', 'AssetState'], 0.4933158985648832)
# (['Damage', 'AssetState'], 0.14789458706222888)
# (['Maintained', 'Damage', 'AssetState'], 0.13503418818725244)
# (['Maintained'], 0.5643545670564479)
# (['Damage'], 0.7472207443109887)
# (['AssetState'], 0.009102907107000803)
# (['Maintained', 'Damage'], 0.436938676318186)
# (['Maintained', 'AssetState'], 0.005662903592324365)
# (['Damage', 'AssetState'], 0.00020705303327976)
# (['Maintained', 'Damage', 'AssetState'], 0.00018853074924780652)
# (['Maintained'], 0.6220567564923217)
# (['Damage'], 0.023267800640737243)
# (['AssetState'], 0.9992860554937735)
# (['Maintained', 'Damage'], 0.02101094168264804)
# (['Maintained', 'AssetState'], 0.6216542173723004)
# (['Damage', 'AssetState'], 0.022729574900860746)
# (['Maintained', 'Damage', 'AssetState'], 0.02069626181401278)
# (['Maintained'], 0.49895468527857845)
# (['Damage'], 0.6896862857334533)
# (['AssetState'], 0.562279091807945)
# (['Maintained', 'Damage'], 0.3151546603682668)
# (['Maintained', 'AssetState'], 0.4215718840192851)
# (['Damage', 'AssetState'], 0.2626288836402224)
# (['Maintained', 'Damage', 'AssetState'], 0.23979158941063786)
# (['Maintained'], 0.577639923638903)
# (['Damage'], 0.9118637779372343)
# (['AssetState'], 0.003354381356128011)
# (['Maintained', 'Damage'], 0.5332139868276622)
# (['Maintained', 'AssetState'], 0.00213881434618864)
# (['Damage', 'AssetState'], 0.0002526752135795452)
# (['Maintained', 'Damage', 'AssetState'], 0.00023007171920121707)
# (['Maintained'], 0.6375009955189268)
# (['Damage'], 0.07696054565861295)
# (['AssetState'], 0.9980537060907536)
# (['Maintained', 'Damage'], 0.06949576204752342)
# (['Maintained', 'AssetState'], 0.6363771313461177)
# (['Damage', 'AssetState'], 0.07518031093561621)
# (['Maintained', 'Damage', 'AssetState'], 0.06845492734329489)
# (['Maintained'], 0.2074042948191091)
# (['Damage'], 0.7789861616399842)
# (['AssetState'], 0.06279524264578264)
# (['Maintained', 'Damage'], 0.14179161034175577)
# (['Maintained', 'AssetState'], 0.03989269697110893)
# (['Damage', 'AssetState'], 0.00586970309190134)
# (['Maintained', 'Damage', 'AssetState'], 0.00535929412738818)
# (['Maintained'], 0.6352374359794504)
# (['Damage'], 0.09354533350654684)
# (['AssetState'], 0.9999020529439462)
# (['Maintained', 'Damage'], 0.08535144289760026)
# (['Maintained', 'AssetState'], 0.6352199293804545)
# (['Damage', 'AssetState'], 0.09346453528128462)
# (['Maintained', 'Damage', 'AssetState'], 0.08533718438725986)
# (['Maintained'], 0.6159432564247083)
# (['Damage'], 0.02682510441819806)
# (['AssetState'], 0.9683875645922143)
# (['Maintained', 'Damage'], 0.018679385905841936)
# (['Maintained', 'AssetState'], 0.5986442755035529)
# (['Damage', 'AssetState'], 0.009192843057771866)
# (['Maintained', 'Damage', 'AssetState'], 0.00837048152324096)
# (['Maintained'], 0.5181345040123886)
# (['Damage'], 0.5479812141426936)
# (['AssetState'], 0.6451541220430795)
# (['Maintained', 'Damage'], 0.25040201176056875)
# (['Maintained', 'AssetState'], 0.4553137198821905)
# (['Damage', 'AssetState'], 0.20866834313380736)
# (['Maintained', 'Damage', 'AssetState'], 0.1905232698178241)
# (['Maintained'], 0.5726054686955188)
# (['Damage'], 0.8494726836983268)
# (['AssetState'], 0.005532771804591651)
# (['Maintained', 'Damage'], 0.4967306820768969)
# (['Maintained', 'AssetState'], 0.0034742597605455167)
# (['Damage', 'AssetState'], 0.00023538679458132662)
# (['Maintained', 'Damage', 'AssetState'], 0.0002143298653610938)
# (['Maintained'], 0.6278764275285894)
# (['Damage'], 0.043500206555975356)
# (['AssetState'], 0.9988216837552266)
# (['Maintained', 'Damage'], 0.039280906573118314)
# (['Maintained', 'AssetState'], 0.6272020799685271)
# (['Damage', 'AssetState'], 0.042493969171536916)
# (['Maintained', 'Damage', 'AssetState'], 0.03869259831416431)
# (['Maintained'], 0.21769753935081454)
# (['Damage'], 0.6893633186518417)
# (['AssetState'], 0.08520368192216903)
# (['Maintained', 'Damage'], 0.1254783972752468)
# (['Maintained', 'AssetState'], 0.05327967224951578)
# (['Damage', 'AssetState'], 0.005194390095987543)
# (['Maintained', 'Damage', 'AssetState'], 0.0047427040006842785)
# (['Maintained'], 0.6252898449369633)
# (['Damage'], 0.06101278836937296)
# (['AssetState'], 0.9999295369190787)
# (['Maintained', 'Damage'], 0.05566851201794532)
# (['Maintained', 'AssetState'], 0.625277180489976)
# (['Damage', 'AssetState'], 0.060960089588645426)
# (['Maintained', 'Damage', 'AssetState'], 0.055659212233111044)
# (['Maintained'], 0.6151364840208045)
# (['Damage'], 0.017059369211609908)
# (['AssetState'], 0.9746663361411465)
# (['Maintained', 'Damage'], 0.01187911651138711)
# (['Maintained', 'AssetState'], 0.6015203363588323)
# (['Damage', 'AssetState'], 0.0058461693711255895)
# (['Maintained', 'Damage', 'AssetState'], 0.005323190268256876)
# (['Maintained'], 0.187496890143424)
# (['Damage'], 0.9523190886927455)
# (['AssetState'], 0.019456733835322326)
# (['Maintained', 'Damage'], 0.1733417919269065)
# (['Maintained', 'AssetState'], 0.014001935955011547)
# (['Damage', 'AssetState'], 0.007175776123684039)
# (['Maintained', 'Damage', 'AssetState'], 0.006551795591189775)
# (['Maintained'], 0.7194652787490865)
# (['Damage'], 0.3690035911898951)
# (['AssetState'], 0.9996693417351469)
# (['Maintained', 'Damage'], 0.33668156135495053)
# (['Maintained', 'AssetState'], 0.7194067728753609)
# (['Damage', 'AssetState'], 0.36868487047806564)
# (['Maintained', 'Damage', 'AssetState'], 0.33662531652345123)
# (['Maintained'], 0.6248878726313024)
# (['Damage'], 0.13509697015811248)
# (['AssetState'], 0.8987753648165165)
# (['Maintained', 'Damage'], 0.09407338741173514)
# (['Maintained', 'AssetState'], 0.5667576363314648)
# (['Damage', 'AssetState'], 0.04629712618756851)
# (['Maintained', 'Damage', 'AssetState'], 0.042155537399778654)
# (['Maintained'], 0.6076251499850784)
# (['Damage'], 0.006266126425571711)
# (['AssetState'], 0.998069440161393)
# (['Maintained', 'Damage'], 0.0054192077127912745)
# (['Maintained', 'AssetState'], 0.6072647948943061)
# (['Damage', 'AssetState'], 0.005856067681725487)
# (['Maintained', 'Damage', 'AssetState'], 0.005346844405053706)
# (['Maintained'], 0.39102745132090755)
# (['Damage'], 0.8465777350674435)
# (['AssetState'], 0.12555566994462117)
# (['Maintained', 'Damage'], 0.33175068354655396)
# (['Maintained', 'AssetState'], 0.05769939187709225)
# (['Damage', 'AssetState'], 0.013685306568929488)
# (['Maintained', 'Damage', 'AssetState'], 0.011207798027924688)
# (['Maintained'], 0.34261775783514437)
# (['Damage'], 0.41389565025485114)
# (['AssetState'], 0.6633307537157676)
# (['Maintained', 'Damage'], 0.11265798764333233)
# (['Maintained', 'AssetState'], 0.31315083662368687)
# (['Damage', 'AssetState'], 0.1040861842356875)
# (['Maintained', 'Damage', 'AssetState'], 0.08571803407644853)
# (['Maintained'], 0.3653828530484145)
# (['Damage'], 0.7348861082895101)
# (['AssetState'], 0.00867751291301613)
# (['Maintained', 'Damage'], 0.2828893562304919)
# (['Maintained', 'AssetState'], 0.0036663615249783793)
# (['Damage', 'AssetState'], 0.00014904333051031043)
# (['Maintained', 'Damage', 'AssetState'], 0.00012206139024764667)
# (['Maintained'], 0.42246976493703475)
# (['Damage'], 0.017718255599929466)
# (['AssetState'], 0.9992507610226121)
# (['Maintained', 'Damage'], 0.01426957829994028)
# (['Maintained', 'AssetState'], 0.4221963805462401)
# (['Damage', 'AssetState'], 0.017162943222403894)
# (['Maintained', 'Damage', 'AssetState'], 0.014055863508250858)
# (['Maintained'], 0.30680234093793374)
# (['Damage'], 0.7119511084441229)
# (['AssetState'], 0.4538892493236945)
# (['Maintained', 'Damage'], 0.19378550880727624)
# (['Maintained', 'AssetState'], 0.25922041561453324)
# (['Damage', 'AssetState'], 0.17904095922411398)
# (['Maintained', 'Damage', 'AssetState'], 0.14744549583162328)
# (['Maintained'], 0.3780489463356871)
# (['Damage'], 0.9065584150606735)
# (['AssetState'], 0.0031897901201494716)
# (['Maintained', 'Damage'], 0.34897343075209925)
# (['Maintained', 'AssetState'], 0.0013997933260750995)
# (['Damage', 'AssetState'], 0.00018386044307910866)
# (['Maintained', 'Damage', 'AssetState'], 0.00015057541465924107)
# (['Maintained'], 0.4387107382021375)
# (['Damage'], 0.059383466026102595)
# (['AssetState'], 0.9979531467513845)
# (['Maintained', 'Damage'], 0.047825081504337695)
# (['Maintained', 'AssetState'], 0.4379373256359491)
# (['Damage', 'AssetState'], 0.05752231363902474)
# (['Maintained', 'Damage', 'AssetState'], 0.04710880754610362)
# (['Maintained'], 0.10418427935948837)
# (['Damage'], 0.7914020341195499)
# (['AssetState'], 0.045924235230178884)
# (['Maintained', 'Damage'], 0.07122541389782326)
# (['Maintained', 'AssetState'], 0.0200390830347381)
# (['Damage', 'AssetState'], 0.003268984979111762)
# (['Maintained', 'Damage', 'AssetState'], 0.0026921052769155692)
# (['Maintained'], 0.4363034703222096)
# (['Damage'], 0.07128504982816328)
# (['AssetState'], 0.9998636648302356)
# (['Maintained', 'Damage'], 0.05862238058406174)
# (['Maintained', 'AssetState'], 0.4362914461727139)
# (['Damage', 'AssetState'], 0.07117242747989787)
# (['Maintained', 'Damage', 'AssetState'], 0.058612587336386475)
# (['Maintained'], 0.4161579314618663)
# (['Damage'], 0.025003702067114667)
# (['AssetState'], 0.9665527830251824)
# (['Maintained', 'Damage'], 0.012620601846792598)
# (['Maintained', 'AssetState'], 0.4044699909877159)
# (['Damage', 'AssetState'], 0.006905611597683084)
# (['Maintained', 'Damage', 'AssetState'], 0.005655459719246945)
# (['Maintained'], 0.32336279001764867)
# (['Damage'], 0.5741352552197825)
# (['AssetState'], 0.550731494064784)
# (['Maintained', 'Damage'], 0.15627350142076926)
# (['Maintained', 'AssetState'], 0.2841569392778732)
# (['Damage', 'AssetState'], 0.14438312631266728)
# (['Maintained', 'Damage', 'AssetState'], 0.11890375108102012)
# (['Maintained'], 0.3732168942202803)
# (['Damage'], 0.8410662767764951)
# (['AssetState'], 0.005283329298222839)
# (['Maintained', 'Damage'], 0.32376268227232147)
# (['Maintained', 'AssetState'], 0.0022644779144342818)
# (['Damage', 'AssetState'], 0.00017057788636452414)
# (['Maintained', 'Damage', 'AssetState'], 0.00013969745498755188)
# (['Maintained'], 0.42853940814770475)
# (['Damage'], 0.033289549109028815)
# (['AssetState'], 0.9987658112894365)
# (['Maintained', 'Damage'], 0.026810078729357808)
# (['Maintained', 'AssetState'], 0.42807915117419093)
# (['Damage', 'AssetState'], 0.03224621284162771)
# (['Maintained', 'Damage', 'AssetState'], 0.026408545462544612)
# (['Maintained'], 0.11006620782805226)
# (['Damage'], 0.704906681267786)
# (['AssetState'], 0.06325399707039886)
# (['Maintained', 'Damage'], 0.06344091620701428)
# (['Maintained', 'AssetState'], 0.026937794043576865)
# (['Damage', 'AssetState'], 0.0029117051174925588)
# (['Maintained', 'Damage', 'AssetState'], 0.0023978748026409306)
# (['Maintained'], 0.4258342994597911)
# (['Damage'], 0.046100314033651994)
# (['AssetState'], 0.9999028108353545)
# (['Maintained', 'Damage'], 0.0379113174619372)
# (['Maintained', 'AssetState'], 0.42582567473006844)
# (['Damage', 'AssetState'], 0.046027480730809985)
# (['Maintained', 'Damage', 'AssetState'], 0.03790498413125528)
# (['Maintained'], 0.4153298507212069)
# (['Damage'], 0.015890225174121496)
# (['AssetState'], 0.9730057961506802)
# (['Maintained', 'Damage'], 0.008020580498046624)
# (['Maintained', 'AssetState'], 0.406136455884861)
# (['Damage', 'AssetState'], 0.004388619051597575)
# (['Maintained', 'Damage', 'AssetState'], 0.003594128907822894)
# (['Maintained'], 0.09302153353867385)
# (['Damage'], 0.9555532378831103)
# (['AssetState'], 0.013035748470859258)
# (['Maintained', 'Damage'], 0.08599886269605993)
# (['Maintained', 'AssetState'], 0.006946683510585952)
# (['Damage', 'AssetState'], 0.003947032035186339)
# (['Maintained', 'Damage', 'AssetState'], 0.0032504969701534553)
# (['Maintained'], 0.5326735103273132)
# (['Damage'], 0.3031137235531789)
# (['AssetState'], 0.9995033209091246)
# (['Maintained', 'Damage'], 0.24927033235187923)
# (['Maintained', 'AssetState'], 0.5326301940894729)
# (['Damage', 'AssetState'], 0.30263483801658575)
# (['Maintained', 'Damage', 'AssetState'], 0.2492286901313059)
# (['Maintained'], 0.4254149765473338)
# (['Damage'], 0.12688249521067702)
# (['AssetState'], 0.8944150910022021)
# (['Maintained', 'Damage'], 0.0640438543493776)
# (['Maintained', 'AssetState'], 0.3858407197961914)
# (['Damage', 'AssetState'], 0.03504285997801165)
# (['Maintained', 'Damage', 'AssetState'], 0.028698903818938894)
# (['Maintained'], 0.4076739122617183)
# (['Damage'], 0.004914410810630962)
# (['AssetState'], 0.997387857837926)
# (['Maintained', 'Damage'], 0.0036359087665919524)
# (['Maintained', 'AssetState'], 0.40743213923823135)
# (['Damage', 'AssetState'], 0.004356077639500002)
# (['Maintained', 'Damage', 'AssetState'], 0.0035873580560588252)
# (['Maintained'], 0.03159374799784125)
# (['Damage'], 0.8529403716178526)
# (['AssetState'], 0.20654963566598863)
# (['Maintained', 'Damage'], 0.024460883475324963)
# (['Maintained', 'AssetState'], 0.02566602511843174)
# (['Damage', 'AssetState'], 0.06912858373461404)
# (['Maintained', 'Damage', 'AssetState'], 0.01861154177470378)
# (['Maintained'], 0.04640229077333044)
# (['Damage'], 0.9461074047581983)
# (['AssetState'], 0.0015729874423164021)
# (['Maintained', 'Damage'], 0.044546542489627694)
# (['Maintained', 'AssetState'], 9.895247158912465e-05)
# (['Damage', 'AssetState'], 7.303965195062759e-05)
# (['Maintained', 'Damage', 'AssetState'], 1.9220987949011203e-05)
# (['Maintained'], 0.06283876763236305)
# (['Damage'], 0.05017207004607924)
# (['AssetState'], 0.995851302704299)
# (['Maintained', 'Damage'], 0.01235374277463462)
# (['Maintained', 'AssetState'], 0.0626463664533302)
# (['Damage', 'AssetState'], 0.046241076430329375)
# (['Maintained', 'Damage', 'AssetState'], 0.012168721359973978)
# (['Maintained'], 0.008376545526769537)
# (['Damage'], 0.9081656203084555)
# ...
# (['Maintained', 'Damage', 'AssetState'], 0.005000000000000005)
# (['Maintained'], 0.8199710549999999)
# (['Damage'], 0.36394999999999994)
# (['AssetState'], 0.855)
# (['Maintained', 'Damage'], 0.7482499999999997)
# (['Maintained', 'AssetState'], 0.8549999999999999)
# (['Damage', 'AssetState'], 0.855)
# (['Maintained', 'Damage', 'AssetState'], 0.8549999999999999)
# (['Maintained'], 0.06435397568)
# (['Damage'], 0.012000300919999997)
# (['AssetState'], 0.09499999999999999)
# (['Maintained', 'Damage'], 0.0151428596)
# (['Maintained', 'AssetState'], 0.095)
# (['Damage', 'AssetState'], 0.09499999999999999)
# (['Maintained', 'Damage', 'AssetState'], 0.09499999999999995)
# (['Maintained'], 0.07323085999999997)
# (['Damage'], 0.51445)
# (['AssetState'], 0.0050000000000000044)
# (['Maintained', 'Damage'], 0.11574999999999998)
# (['Maintained', 'AssetState'], 0.005000000000000005)
# (['Damage', 'AssetState'], 0.005000000000000005)
# (['Maintained', 'Damage', 'AssetState'], 0.005000000000000006)
# (['Maintained'], 0.78923346)
# (['Damage'], 0.36395000000000005)
# (['AssetState'], 0.855)
# (['Maintained', 'Damage'], 0.7482499999999999)
# (['Maintained', 'AssetState'], 0.855)
# (['Damage', 'AssetState'], 0.8549999999999999)
# (['Maintained', 'Damage', 'AssetState'], 0.8549999999999999)
# (['Maintained'], 0.04326349736000001)
# (['Damage'], 0.012000300919999998)
# (['AssetState'], 0.095)
# (['Maintained', 'Damage'], 0.015142859600000001)
# (['Maintained', 'AssetState'], 0.09499999999999997)
# (['Damage', 'AssetState'], 0.09499999999999997)
# (['Maintained', 'Damage', 'AssetState'], 0.09499999999999997)
# (['Maintained'], 0.09302017249999993)
# (['Damage'], 0.045550000000000014)
# (['AssetState'], 0.09499999999999997)
# (['Maintained', 'Damage'], 0.08425)
# (['Maintained', 'AssetState'], 0.09499999999999995)
# (['Damage', 'AssetState'], 0.095)
# (['Maintained', 'Damage', 'AssetState'], 0.095)
# (['Maintained'], 0.057286182499999984)
# (['Damage'], 0.51445)
# (['AssetState'], 0.0050000000000000044)
# (['Maintained', 'Damage'], 0.11575000000000002)
# (['Maintained', 'AssetState'], 0.005000000000000006)
# (['Damage', 'AssetState'], 0.005000000000000006)
# (['Maintained', 'Damage', 'AssetState'], 0.005000000000000006)
# (['Maintained'], 0.8046022575)
# (['Damage'], 0.36395)
# (['AssetState'], 0.855)
# (['Maintained', 'Damage'], 0.7482499999999999)
# (['Maintained', 'AssetState'], 0.8550000000000001)
# (['Damage', 'AssetState'], 0.8549999999999999)
# (['Maintained', 'Damage', 'AssetState'], 0.8549999999999998)
# (['Maintained'], 0.05380873652000002)
# (['Damage'], 0.012000300920000003)
# (['AssetState'], 0.095)
# (['Maintained', 'Damage'], 0.015142859600000003)
# (['Maintained', 'AssetState'], 0.09499999999999999)
# (['Damage', 'AssetState'], 0.095)
# (['Maintained', 'Damage', 'AssetState'], 0.09499999999999999)
# (['Maintained'], 0.093536065)
# (['Damage'], 0.04555000000000001)
# (['AssetState'], 0.09500000000000001)
# (['Maintained', 'Damage'], 0.08425)
# (['Maintained', 'AssetState'], 0.09500000000000001)
# (['Damage', 'AssetState'], 0.095)
# (['Maintained', 'Damage', 'AssetState'], 0.09500000000000003)
# (['Maintained'], 0.089408925)
# (['Damage'], 0.04555)
# (['AssetState'], 0.09499999999999999)
# (['Maintained', 'Damage'], 0.08425)
# (['Maintained', 'AssetState'], 0.09500000000000001)
# (['Damage', 'AssetState'], 0.095)
# (['Maintained', 'Damage', 'AssetState'], 0.09500000000000001)
# (['Maintained'], 0.08917553750000001)
# (['Damage'], 0.7470249999999999)
# (['AssetState'], 0.0050000000000000044)
# (['Maintained', 'Damage'], 0.11575000000000003)
# (['Maintained', 'AssetState'], 0.005000000000000005)
# (['Damage', 'AssetState'], 0.0050000000000000044)
# (['Maintained', 'Damage', 'AssetState'], 0.005000000000000006)
# (['Maintained'], 0.7738646625)
# (['Damage'], 0.13977499999999995)
# (['AssetState'], 0.8549999999999999)
# (['Maintained', 'Damage'], 0.74825)
# (['Maintained', 'AssetState'], 0.8550000000000001)
# (['Damage', 'AssetState'], 0.8549999999999998)
# (['Maintained', 'Damage', 'AssetState'], 0.8550000000000001)
# (['Maintained'], 0.03271825820000001)
# (['Damage'], 0.010167141690000001)
# (['AssetState'], 0.09500000000000001)
# (['Maintained', 'Damage'], 0.0151428596)
# (['Maintained', 'AssetState'], 0.09500000000000001)
# (['Damage', 'AssetState'], 0.09499999999999999)
# (['Maintained', 'Damage', 'AssetState'], 0.09499999999999999)
# (['Maintained'], 0.091472495)
# (['Damage'], 0.022975)
# (['AssetState'], 0.09499999999999999)
# (['Maintained', 'Damage'], 0.08425)
# (['Maintained', 'AssetState'], 0.09499999999999999)
# (['Damage', 'AssetState'], 0.09499999999999999)
# (['Maintained', 'Damage', 'AssetState'], 0.09500000000000001)
# (['Maintained'], 0.08837714)
# (['Damage'], 0.022975)
# (['AssetState'], 0.095)
# (['Maintained', 'Damage'], 0.08425)
# (['Maintained', 'AssetState'], 0.095)
# (['Damage', 'AssetState'], 0.09499999999999999)
# (['Maintained', 'Damage', 'AssetState'], 0.09500000000000001)
# (['Maintained'], 0.08992481750000005)
# (['Damage'], 0.022975)
# (['AssetState'], 0.09500000000000001)
# (['Maintained', 'Damage'], 0.08425000000000002)
# (['Maintained', 'AssetState'], 0.09500000000000003)
# (['Damage', 'AssetState'], 0.09500000000000001)
# (['Maintained', 'Damage', 'AssetState'], 0.09500000000000001)
# (['Maintained'], 0.05013033750000003)
# (['Damage'], 0.05175000000000003)
# (['AssetState'], 0.04500000000000004)
# (['Maintained', 'Damage'], 0.05175000000000003)
# (['Maintained', 'AssetState'], 0.04500000000000004)
# (['Damage', 'AssetState'], 0.04500000000000004)
# (['Maintained', 'Damage', 'AssetState'], 0.04500000000000004)
# (['Maintained'], 0.6466467817999999)
# (['Damage'], 0.8277142604)
# (['AssetState'], 0.005000000000000004)
# (['Maintained', 'Damage'], 0.8277142604)
# (['Maintained', 'AssetState'], 0.005000000000000004)
# (['Damage', 'AssetState'], 0.005000000000000005)
# (['Maintained', 'Damage', 'AssetState'], 0.005000000000000005)
# (['Maintained'], 0.2365278198)
# (['Damage'], 0.062000024399999985)
# (['AssetState'], 0.8549999999999999)
# (['Maintained', 'Damage'], 0.062000024399999985)
# (['Maintained', 'AssetState'], 0.8549999999999999)
# (['Damage', 'AssetState'], 0.8549999999999999)
# (['Maintained', 'Damage', 'AssetState'], 0.8549999999999999)
# (['Maintained'], 0.04134150499999997)
# (['Damage'], 0.11575)
# (['AssetState'], 0.005000000000000005)
# (['Maintained', 'Damage'], 0.11575)
# (['Maintained', 'AssetState'], 0.005000000000000005)
# (['Damage', 'AssetState'], 0.0050000000000000044)
# (['Maintained', 'Damage', 'AssetState'], 0.0050000000000000044)
# (['Maintained'], 0.8199710549999999)
# (['Damage'], 0.74825)
# (['AssetState'], 0.855)
# (['Maintained', 'Damage'], 0.74825)
# (['Maintained', 'AssetState'], 0.855)
# (['Damage', 'AssetState'], 0.855)
# (['Maintained', 'Damage', 'AssetState'], 0.855)
# (['Maintained'], 0.06435397567999998)
# (['Damage'], 0.015142859600000004)
# (['AssetState'], 0.09499999999999997)
# (['Maintained', 'Damage'], 0.015142859600000004)
# (['Maintained', 'AssetState'], 0.09499999999999997)
# (['Damage', 'AssetState'], 0.09499999999999999)
# (['Maintained', 'Damage', 'AssetState'], 0.09499999999999999)
# (['Maintained'], 0.07323085999999998)
# (['Damage'], 0.11575)
# (['AssetState'], 0.0050000000000000044)
# (['Maintained', 'Damage'], 0.11575)
# (['Maintained', 'AssetState'], 0.0050000000000000044)
# (['Damage', 'AssetState'], 0.005000000000000004)
# (['Maintained', 'Damage', 'AssetState'], 0.005000000000000004)
# (['Maintained'], 0.78923346)
# (['Damage'], 0.74825)
# (['AssetState'], 0.8549999999999998)
# (['Maintained', 'Damage'], 0.74825)
# (['Maintained', 'AssetState'], 0.8549999999999998)
# (['Damage', 'AssetState'], 0.8549999999999999)
# (['Maintained', 'Damage', 'AssetState'], 0.8549999999999999)
# (['Maintained'], 0.043263497359999986)
# (['Damage'], 0.0151428596)
# (['AssetState'], 0.09499999999999997)
# (['Maintained', 'Damage'], 0.0151428596)
# (['Maintained', 'AssetState'], 0.09499999999999997)
# (['Damage', 'AssetState'], 0.09499999999999999)
# (['Maintained', 'Damage', 'AssetState'], 0.09499999999999999)
# (['Maintained'], 0.09302017249999998)
# (['Damage'], 0.08424999999999998)
# (['AssetState'], 0.095)
# (['Maintained', 'Damage'], 0.08424999999999998)
# (['Maintained', 'AssetState'], 0.095)
# (['Damage', 'AssetState'], 0.09499999999999999)
# (['Maintained', 'Damage', 'AssetState'], 0.09499999999999999)
# (['Maintained'], 0.05728618249999997)
# (['Damage'], 0.11575)
# (['AssetState'], 0.005000000000000004)
# (['Maintained', 'Damage'], 0.11575)
# (['Maintained', 'AssetState'], 0.005000000000000004)
# (['Damage', 'AssetState'], 0.0050000000000000044)
# (['Maintained', 'Damage', 'AssetState'], 0.0050000000000000044)
# (['Maintained'], 0.8046022575)
# (['Damage'], 0.7482499999999999)
# (['AssetState'], 0.8549999999999999)
# (['Maintained', 'Damage'], 0.7482499999999999)
# (['Maintained', 'AssetState'], 0.8549999999999999)
# (['Damage', 'AssetState'], 0.855)
# (['Maintained', 'Damage', 'AssetState'], 0.855)
# (['Maintained'], 0.05380873651999998)
# (['Damage'], 0.015142859600000001)
# (['AssetState'], 0.09499999999999999)
# (['Maintained', 'Damage'], 0.015142859600000001)
# (['Maintained', 'AssetState'], 0.09499999999999999)
# (['Damage', 'AssetState'], 0.095)
# (['Maintained', 'Damage', 'AssetState'], 0.095)
# (['Maintained'], 0.09353606500000004)
# (['Damage'], 0.08424999999999998)
# (['AssetState'], 0.09500000000000003)
# (['Maintained', 'Damage'], 0.08424999999999998)
# (['Maintained', 'AssetState'], 0.09500000000000003)
# (['Damage', 'AssetState'], 0.095)
# (['Maintained', 'Damage', 'AssetState'], 0.095)
# (['Maintained'], 0.08940892500000003)
# (['Damage'], 0.08425000000000002)
# (['AssetState'], 0.09500000000000001)
# (['Maintained', 'Damage'], 0.08425000000000002)
# (['Maintained', 'AssetState'], 0.09500000000000001)
# (['Damage', 'AssetState'], 0.09500000000000003)
# (['Maintained', 'Damage', 'AssetState'], 0.09500000000000003)
# (['Maintained'], 0.08917553750000001)
# (['Damage'], 0.38155000000000006)
# (['AssetState'], 0.0050000000000000044)
# (['Maintained', 'Damage'], 0.11575000000000003)
# (['Maintained', 'AssetState'], 0.0050000000000000044)
# (['Damage', 'AssetState'], 0.005000000000000005)
# (['Maintained', 'Damage', 'AssetState'], 0.005000000000000005)
# (['Maintained'], 0.7738646625)
# (['Damage'], 0.4920499999999998)
# (['AssetState'], 0.8549999999999998)
# (['Maintained', 'Damage'], 0.7482499999999999)
# (['Maintained', 'AssetState'], 0.8549999999999998)
# (['Damage', 'AssetState'], 0.8549999999999999)
# (['Maintained', 'Damage', 'AssetState'], 0.8549999999999999)
# (['Maintained'], 0.032718258199999996)
# (['Damage'], 0.013047820480000001)
# (['AssetState'], 0.09500000000000001)
# (['Maintained', 'Damage'], 0.015142859600000001)
# (['Maintained', 'AssetState'], 0.09500000000000001)
# (['Damage', 'AssetState'], 0.09500000000000001)
# (['Maintained', 'Damage', 'AssetState'], 0.09500000000000001)
# (['Maintained'], 0.09147249500000003)
# (['Damage'], 0.05845000000000001)
# (['AssetState'], 0.095)
# (['Maintained', 'Damage'], 0.08425000000000002)
# (['Maintained', 'AssetState'], 0.09500000000000003)
# (['Damage', 'AssetState'], 0.09500000000000001)
# (['Maintained', 'Damage', 'AssetState'], 0.09500000000000003)
# (['Maintained'], 0.08837714000000002)
# (['Damage'], 0.05845000000000001)
# (['AssetState'], 0.09500000000000004)
# (['Maintained', 'Damage'], 0.08424999999999999)
# (['Maintained', 'AssetState'], 0.09500000000000003)
# (['Damage', 'AssetState'], 0.09500000000000001)
# (['Maintained', 'Damage', 'AssetState'], 0.09500000000000001)
# (['Maintained'], 0.08992481750000005)
# (['Damage'], 0.05845)
# (['AssetState'], 0.095)
# (['Maintained', 'Damage'], 0.08425)
# (['Maintained', 'AssetState'], 0.095)
# (['Damage', 'AssetState'], 0.09500000000000001)
# (['Maintained', 'Damage', 'AssetState'], 0.09500000000000001)
# (['Maintained'], 0.08917553750000001)
# (['Damage'], 0.5144499999999999)
# (['AssetState'], 0.0050000000000000044)
# (['Maintained', 'Damage'], 0.11575000000000003)
# (['Maintained', 'AssetState'], 0.005000000000000005)
# (['Damage', 'AssetState'], 0.005000000000000006)
# (['Maintained', 'Damage', 'AssetState'], 0.005000000000000006)
# (['Maintained'], 0.7738646625)
# (['Damage'], 0.3639499999999999)
# (['AssetState'], 0.8549999999999996)
# (['Maintained', 'Damage'], 0.74825)
# (['Maintained', 'AssetState'], 0.8550000000000001)
# (['Damage', 'AssetState'], 0.855)
# (['Maintained', 'Damage', 'AssetState'], 0.8550000000000001)
# (['Maintained'], 0.03271825820000001)
# (['Damage'], 0.01200030092)
# (['AssetState'], 0.095)
# (['Maintained', 'Damage'], 0.0151428596)
# (['Maintained', 'AssetState'], 0.09500000000000001)
# (['Damage', 'AssetState'], 0.09499999999999997)
# (['Maintained', 'Damage', 'AssetState'], 0.09499999999999999)
# (['Maintained'], 0.091472495)
# (['Damage'], 0.04555)
# (['AssetState'], 0.095)
# (['Maintained', 'Damage'], 0.08425)
# (['Maintained', 'AssetState'], 0.09499999999999999)
# (['Damage', 'AssetState'], 0.09500000000000003)
# (['Maintained', 'Damage', 'AssetState'], 0.09500000000000001)
# (['Maintained'], 0.08837714)
# (['Damage'], 0.04555000000000001)
# (['AssetState'], 0.095)
# (['Maintained', 'Damage'], 0.08425)
# (['Maintained', 'AssetState'], 0.095)
# (['Damage', 'AssetState'], 0.09499999999999999)
# (['Maintained', 'Damage', 'AssetState'], 0.09500000000000001)
# (['Maintained'], 0.08992481750000005)
# (['Damage'], 0.045550000000000014)
# (['AssetState'], 0.095)
# (['Maintained', 'Damage'], 0.08425000000000002)
# (['Maintained', 'AssetState'], 0.09500000000000003)
# (['Damage', 'AssetState'], 0.09500000000000003)
# (['Maintained', 'Damage', 'AssetState'], 0.09500000000000001)
# (['Maintained'], 0.0868294625)
# (['Damage'], 0.022974999999999992)
# (['AssetState'], 0.09499999999999999)
# (['Maintained', 'Damage'], 0.08425)
# (['Maintained', 'AssetState'], 0.095)
# (['Damage', 'AssetState'], 0.095)
# (['Maintained', 'Damage', 'AssetState'], 0.09500000000000001)
# (['Maintained'], 0.08917553749999997)
# (['Damage'], 0.11575)
# (['AssetState'], 0.005000000000000005)
# (['Maintained', 'Damage'], 0.11575)
# (['Maintained', 'AssetState'], 0.005000000000000005)
# (['Damage', 'AssetState'], 0.0050000000000000044)
# (['Maintained', 'Damage', 'AssetState'], 0.0050000000000000044)
# (['Maintained'], 0.7738646624999999)
# (['Damage'], 0.74825)
# (['AssetState'], 0.8549999999999999)
# (['Maintained', 'Damage'], 0.74825)
# (['Maintained', 'AssetState'], 0.8549999999999999)
# (['Damage', 'AssetState'], 0.8549999999999999)
# (['Maintained', 'Damage', 'AssetState'], 0.8549999999999999)
# (['Maintained'], 0.0327182582)
# (['Damage'], 0.015142859600000003)
# (['AssetState'], 0.095)
# (['Maintained', 'Damage'], 0.015142859600000003)
# (['Maintained', 'AssetState'], 0.095)
# (['Damage', 'AssetState'], 0.09500000000000001)
# (['Maintained', 'Damage', 'AssetState'], 0.09500000000000001)
# (['Maintained'], 0.09147249500000001)
# (['Damage'], 0.08424999999999999)
# (['AssetState'], 0.095)
# (['Maintained', 'Damage'], 0.08424999999999999)
# (['Maintained', 'AssetState'], 0.095)
# (['Damage', 'AssetState'], 0.09499999999999999)
# (['Maintained', 'Damage', 'AssetState'], 0.09499999999999999)
# (['Maintained'], 0.08837714)
# (['Damage'], 0.08424999999999999)
# (['AssetState'], 0.095)
# (['Maintained', 'Damage'], 0.08424999999999999)
# (['Maintained', 'AssetState'], 0.095)
# (['Damage', 'AssetState'], 0.095)
# (['Maintained', 'Damage', 'AssetState'], 0.095)
# (['Maintained'], 0.0899248175)
# (['Damage'], 0.08425)
# (['AssetState'], 0.09499999999999999)
# (['Maintained', 'Damage'], 0.08425)
# (['Maintained', 'AssetState'], 0.09499999999999999)
# (['Damage', 'AssetState'], 0.095)
# (['Maintained', 'Damage', 'AssetState'], 0.095)
# (['Maintained'], 0.08682946250000002)
# (['Damage'], 0.05844999999999999)
# (['AssetState'], 0.09499999999999999)
# (['Maintained', 'Damage'], 0.08425000000000002)
# (['Maintained', 'AssetState'], 0.095)
# (['Damage', 'AssetState'], 0.095)
# (['Maintained', 'Damage', 'AssetState'], 0.095)
# (['Maintained'], 0.0868294625)
# (['Damage'], 0.04554999999999999)
# (['AssetState'], 0.09499999999999999)
# (['Maintained', 'Damage'], 0.08425)
# (['Maintained', 'AssetState'], 0.095)
# (['Damage', 'AssetState'], 0.09500000000000003)
# (['Maintained', 'Damage', 'AssetState'], 0.09500000000000001)
# (['Maintained'], 0.0868294625)
# (['Damage'], 0.08424999999999999)
# (['AssetState'], 0.09500000000000001)
# (['Maintained', 'Damage'], 0.08424999999999999)
# (['Maintained', 'AssetState'], 0.09500000000000001)
# (['Damage', 'AssetState'], 0.095)
# (['Maintained', 'Damage', 'AssetState'], 0.095)

# %%
truth_dict = get_possible_truths(rmdg, bnodes, observations)
possibly_true = list(truth_dict.keys())
possibly_false = list(truth_dict.values())

# %%
# for all possible truth value combinations, columns: True nodes, False nodes (or not), FBE1, probability1, FBE2, probability2
original_data = {}
original_data['True Nodes'] = possibly_true
original_data['False Nodes'] = possibly_false
original_data['Best Explanation'] = [v[0] for v in list(fbe1.values())]
original_data['Prob. of best expl.'] = [v[1] for v in list(fbe1.values())]
original_data['Best Explanation (flipped)'] = [v[0] for v in list(fbe2.values())]
original_data['Prob. of best expl. (flipped)'] = [v[1] for v in list(fbe2.values())]

df1 = pd.DataFrame(original_data, columns=list(original_data.keys()))
df1
# Out:
#                                             True Nodes  \
# 0                               (PeriodicMaintenance,)
# 1                                (TonnageMaintenance,)
# 2                                       (RailTraffic,)
# 3                                      (PressureMaps,)
# 4                                       (WeatherMaps,)
# ..                                                 ...
# 250  (PeriodicMaintenance, TonnageMaintenance, Rail...
# 251  (PeriodicMaintenance, TonnageMaintenance, Pres...
# 252  (PeriodicMaintenance, RailTraffic, PressureMap...
# 253  (TonnageMaintenance, RailTraffic, PressureMaps...
# 254  (PeriodicMaintenance, TonnageMaintenance, Rail...
#
#                                            False Nodes Best Explanation  \
# 0    [WeatherMaps, AssetFailure, RailTraffic, Repla...     [AssetState]
# 1    [WeatherMaps, AssetFailure, RailTraffic, Repla...     [AssetState]
# 2    [WeatherMaps, AssetFailure, Replaced, Pressure...     [AssetState]
# 3    [WeatherMaps, AssetFailure, RailTraffic, Repla...     [AssetState]
# 4    [AssetFailure, RailTraffic, Replaced, Pressure...         [Damage]
# ..                                                 ...              ...
# 250                                     [PressureMaps]     [Maintained]
# 251                                      [RailTraffic]     [Maintained]
# 252                               [TonnageMaintenance]     [AssetState]
# 253                              [PeriodicMaintenance]     [AssetState]
# 254                                                 []     [Maintained]
#
#      Prob. of best expl. Best Explanation (flipped)  \
# 0               0.733839                   [Damage]
# 1               0.716161                   [Damage]
# 2               0.530019                   [Damage]
# 3               0.581962                   [Damage]
# 4               0.645996                   [Damage]
# ..                   ...                        ...
# 250             1.000000               [AssetState]
# 251             1.000000       [Damage, AssetState]
# 252             0.956806   [Maintained, AssetState]
# 253             0.931608       [Damage, AssetState]
# 254             1.000000               [AssetState]
#
#      Prob. of best expl. (flipped)
# 0                         0.096458
# 1                         0.097116
# 2                         0.098267
# 3                         0.098267
# 4                         0.098267
# ..                             ...
# 250                       0.095000
# 251                       0.095000
# 252                       0.095000
# 253                       0.095000
# 254                       0.095000
#
# [255 rows x 6 columns]

# %% [markdown]
# # Generate new edges to create a common cause

# %%
blockPrint()
fbe1 = get_all_FBE(rmdg, observations, bnodes)

# %%
fbe1_result =[tuple(v[0]) for v in list(fbe1.values())]
fbe1_count = dict(Counter(fbe1_result))
    
fbe1_count
# Out:
# {('AssetState',): 117, ('Damage',): 68, ('Maintained',): 70}

# %% [markdown]
# ### Testing similarity - haven't done anything with it yet.

# %%
# generate edges to connect Damage and Maintained (the two parent hypotheses of AssetState) through common parents. 

# calculate similarity between parents of Damage and Maintained - in case this could help us pick where to generate an edge
d_parents = list(rmdg.predecessors('Damage'))
m_parents = list(rmdg.predecessors('Maintained'))

parents_pairs = []
parentsJI, parentsIS, parentsFS = {}, {}, {}
for d in d_parents:
    for m in m_parents:
        parents_pairs.append((d,m)) 
        parentsJI[(d,m)] = calculate_jaccard_similarity(rmdg, d, m)
        parentsIS[(d,m)] = get_immediate_similarity(rmdg, d, m)
        parentsFS[(d,m)] = get_full_similarity(rmdg, d, m)

parentsJI, parentsIS, parentsFS
# Out:
# ({('RailTraffic', 'PeriodicMaintenance'): 0.6202087247418423,
#   ('RailTraffic', 'TonnageMaintenance'): 0.5711356450910858,
#   ('PressureMaps', 'PeriodicMaintenance'): 0.6487581307052916,
#   ('PressureMaps', 'TonnageMaintenance'): 0.5952580691615542,
#   ('WeatherMaps', 'PeriodicMaintenance'): 0.57789700633148,
#   ('WeatherMaps', 'TonnageMaintenance'): 0.5350600005531826},
#  {('RailTraffic', 'PeriodicMaintenance'): 1.0,
#   ('RailTraffic', 'TonnageMaintenance'): 1.0,
#   ('PressureMaps', 'PeriodicMaintenance'): 1.0,
#   ('PressureMaps', 'TonnageMaintenance'): 1.0,
#   ('WeatherMaps', 'PeriodicMaintenance'): 1.0,
#   ('WeatherMaps', 'TonnageMaintenance'): 1.0},
#  {('RailTraffic', 'PeriodicMaintenance'): 0.44883881195025,
#   ('RailTraffic', 'TonnageMaintenance'): 0.44827849424385,
#   ('PressureMaps', 'PeriodicMaintenance'): 0.43534110879155,
#   ('PressureMaps', 'TonnageMaintenance'): 0.43478079108515,
#   ('WeatherMaps', 'PeriodicMaintenance'): 0.47129602347075,
#   ('WeatherMaps', 'TonnageMaintenance'): 0.47073570576435})

# %%
max_JI = max(parentsJI, key=parentsJI.get)
max_IS = max(parentsIS, key=parentsIS.get)
max_FS = max(parentsFS, key=parentsFS.get)

max_JI, max_IS, max_FS
# Out:
# (('PressureMaps', 'PeriodicMaintenance'),
#  ('RailTraffic', 'PeriodicMaintenance'),
#  ('WeatherMaps', 'PeriodicMaintenance'))

# %%
parents_pairs = []
parentsJI, parentsIS, parentsFS = {}, {}, {}
for m in m_parents:
    for d in d_parents:
        parents_pairs.append((d,m)) 
        parentsJI[(m,d)] = calculate_jaccard_similarity(rmdg, m,d)
        parentsIS[(m,d)] = get_immediate_similarity(rmdg, m,d)
        parentsFS[(m,d)] = get_full_similarity(rmdg, m,d)

max_JI = max(parentsJI, key=parentsJI.get)
max_IS = max(parentsIS, key=parentsIS.get)
max_FS = max(parentsFS, key=parentsFS.get)

max_JI, max_IS, max_FS
# Out:
# (('PeriodicMaintenance', 'PressureMaps'),
#  ('PeriodicMaintenance', 'RailTraffic'),
#  ('PeriodicMaintenance', 'WeatherMaps'))

# %%
# Generate edges (RailTraffic, Maintained) and (PeriodicMaintenance, Damage)
rmdg.add_weighted_edges_from([('PressureMaps', 'Maintained', .0869213), 
                             ('PeriodicMaintenance', 'Damage', .104758)])

nx.draw_planar(rmdg, with_labels=True)
nx.is_directed_acyclic_graph(rmdg)
# Out:
# True

# %%
# Learn updated CPT 


# Damage
cpt_D = CPT(4)
cpt_D.add_entry([0, 0, 0, 0], (1-.897361, .897361))
cpt_D.add_entry([0, 0, 0, 1], (1-0.0864661, .0864661))
cpt_D.add_entry([0, 0, 1, 0], (1-0.452449, .452449))
cpt_D.add_entry([0, 0, 1, 1], (1-0.523823, 0.523823))
cpt_D.add_entry([0, 1, 0, 0], (1-0.525793, 0.525793))
cpt_D.add_entry([0, 1, 0, 1], (1-0.02309, 0.02309))
cpt_D.add_entry([0, 1, 1, 0], (1-0.55044, 0.55044))
cpt_D.add_entry([0, 1, 1, 1], (1-0.443666, 0.443666))
cpt_D.add_entry([1, 0, 0, 0], (1-0.1, 0.504956))
cpt_D.add_entry([1, 0, 0, 1], (1-0.755279, 0.755279))
cpt_D.add_entry([1, 0, 1, 0], (1-0.48401, 0.48401))
cpt_D.add_entry([1, 0, 1, 1], (1-0.0426066, 0.0426066))
cpt_D.add_entry([1, 1, 0, 0], (1-0.415878, 0.415878))
cpt_D.add_entry([1, 1, 0, 1], (1-0.48176, 0.48176))
cpt_D.add_entry([1, 1, 1, 0], (1-0.722924, 0.722924))
cpt_D.add_entry([1, 1, 1, 1], (1-0.24392, .24392))
rmdg.nodes['Damage']['CPT'] = cpt_D


# Maintained
cpt_M = CPT(3)
cpt_M.add_entry([0, 0, 0], (1-.857672, .857672))
cpt_M.add_entry([0, 0, 1], (1-.751924, .751924))
cpt_M.add_entry([0, 1, 0], (1-.507768, 507768))
cpt_M.add_entry([0, 1, 1], (1-.119625, .119625))
cpt_M.add_entry([1, 0, 0], (1-.372849, .372849))
cpt_M.add_entry([1, 0, 1], (1-.872817, .872817))
cpt_M.add_entry([1, 1, 0], (1-.844437, 844437))
cpt_M.add_entry([1, 1, 1], (1-498706, .498706))
rmdg.nodes['Maintained']['CPT'] = cpt_M

# AssetState - Poor (0) or Good (1)
cpt_AS = CPT(3)
cpt_AS.add_entry([0,1,1], (1-0.0305111, 0.0305111))
cpt_AS.add_entry([0,1,0], (1-0.585991, 0.585991))
cpt_AS.add_entry([0,0,1], (1-0.234251, 0.234251))
cpt_AS.add_entry([0,0,0], (1-0.334416, 0.334416))
cpt_AS.add_entry([1,1,1], (1-0.60196, 0.60196))
cpt_AS.add_entry([1,1,0], (1-0.732915, 0.732915))
cpt_AS.add_entry([1,0,1], (1-0.916999, .916999))
cpt_AS.add_entry([1,0,0], (1-.753021, 0.753021))
rmdg.nodes['AssetState']['CPT'] = cpt_AS


# TestResult
cpt_TR = CPT(1)
cpt_TR.add_entry([0], (1-.955432, .955432))
cpt_TR.add_entry([1], (1-.522981, .522981))
rmdg.nodes['TestResult']['CPT'] = cpt_TR


# AssetFailure
cpt_AF = CPT(1)
cpt_AF.add_entry([0], (1-.249014, .249014))
cpt_AF.add_entry([1], (1-.566034, .566034))
rmdg.nodes['AssetFailure']['CPT'] = cpt_AF

# %% [markdown]
# # Export data

# %%
bnodes = [node for node in list(rmdg.nodes()) if not list(rmdg.predecessors(node)) and list(rmdg.successors(node))] #root nodes
observations = [node for node in list(rmdg.nodes()) if not list(rmdg.successors(node)) and list(rmdg.predecessors(node))] #terminal nodes
hypotheses = findHypotheses(rmdg, observations, bnodes)

# %%
blockPrint()
fbe1_new = get_all_FBE(rmdg, observations, bnodes)
fbe2_new = get_all_FBE(rmdg, observations, bnodes, flipped=True)

# %%
truth_dict = get_possible_truths(rmdg, bnodes, observations)
possibly_true = list(truth_dict.keys())
possibly_false = list(truth_dict.values())

# %%
# for all possible truth value combinations, columns: True nodes, False nodes (or not), FBE1, probability1, FBE2, probability2
new_data = {}
new_data['True Nodes'] = possibly_true
new_data['False Nodes'] = possibly_false
new_data['Best Explanation'] = [v[0] for v in list(fbe1_new.values())]
new_data['Prob. of best expl.'] = [v[1] for v in list(fbe1_new.values())]
new_data['Best Explanation (flipped)'] = [v[0] for v in list(fbe2_new.values())]
new_data['Prob. of best expl. (flipped)'] = [v[1] for v in list(fbe2_new.values())]

df2 = pd.DataFrame(new_data, columns=list(new_data.keys()))
df2
# Out:
#                                             True Nodes  \
# 0                               (PeriodicMaintenance,)
# 1                                (TonnageMaintenance,)
# 2                                       (RailTraffic,)
# 3                                      (PressureMaps,)
# 4                                       (WeatherMaps,)
# ..                                                 ...
# 250  (PeriodicMaintenance, TonnageMaintenance, Rail...
# 251  (PeriodicMaintenance, TonnageMaintenance, Pres...
# 252  (PeriodicMaintenance, RailTraffic, PressureMap...
# 253  (TonnageMaintenance, RailTraffic, PressureMaps...
# 254  (PeriodicMaintenance, TonnageMaintenance, Rail...
#
#                                            False Nodes Best Explanation  \
# 0    [WeatherMaps, AssetFailure, RailTraffic, Repla...     [AssetState]
# 1    [WeatherMaps, AssetFailure, RailTraffic, Repla...     [AssetState]
# 2    [WeatherMaps, AssetFailure, Replaced, Pressure...     [AssetState]
# 3    [WeatherMaps, AssetFailure, RailTraffic, Repla...     [Maintained]
# 4    [AssetFailure, RailTraffic, Replaced, Pressure...     [Maintained]
# ..                                                 ...              ...
# 250                                     [PressureMaps]     [Maintained]
# 251                                      [RailTraffic]     [AssetState]
# 252                               [TonnageMaintenance]     [Maintained]
# 253                              [PeriodicMaintenance]     [AssetState]
# 254                                                 []     [AssetState]
#
#      Prob. of best expl.        Best Explanation (flipped)  \
# 0               0.879908          [Maintained, AssetState]
# 1               0.939707          [Maintained, AssetState]
# 2               0.914683  [Maintained, Damage, AssetState]
# 3               0.999999          [Maintained, AssetState]
# 4               0.894350                      [AssetState]
# ..                   ...                               ...
# 250             0.867275              [Damage, AssetState]
# 251             0.615992                      [AssetState]
# 252             1.000000          [Maintained, AssetState]
# 253             0.561207  [Maintained, Damage, AssetState]
# 254             0.454214          [Maintained, AssetState]
#
#      Prob. of best expl. (flipped)
# 0                         0.207010
# 1                         0.207010
# 2                         0.207010
# 3                         0.207010
# 4                         0.207010
# ..                             ...
# 250                       0.296025
# 251                       0.296025
# 252                       0.296025
# 253                       0.296025
# 254                       0.296025
#
# [255 rows x 6 columns]

# %%
# data to Excel
with pd.ExcelWriter(r'C:\Users\hanaa\OneDrive\amistad 2020\figures\rail-maintenance-data.xlsx') as writer:  
    df1.to_excel(writer, sheet_name='Before Edge Generation')
    df2.to_excel(writer, sheet_name='After Edge Generation')

# %%
# bar chart to probabilities of best explanations before and after generating edges
plt.scatter([v[1] for v in list(fbe1.values())], [v[1] for v in list(fbe1_new.values())])
plt.ylabel('probability AFTER edge generation')
plt.xlabel('Probability BEFORE edge generation')
plt.title('Probability of Observations given Hypotheses')
plt.show()
plt.close()

# %%
# bar chart to probabilities of best explanations before and after generating edges
plt.scatter([v[1] for v in list(fbe2.values())], [v[1] for v in list(fbe2_new.values())])
plt.ylabel('probability AFTER edge generation')
plt.xlabel('Probability BEFORE edge generation')
plt.title('Probability of Hypotheses given Observations')
plt.show()
plt.close()
