# %% [markdown]
# # Exploratory Data Analysis of Similarity Data

# %%
# Import necessary libraries
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import random, itertools as it
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# ## Similarity Distribution of Nodes

# %%
dist_1 = pd.read_csv("Experiment - Similarity Distribution of Nodes/Data/sim-dist-nodes-100-150_1.csv", header=[0], index_col=[0])
dist_1.tail()
# Out:
#       Edit-Distance Immediate Similarity  Edit-Distance Full Similarity  \
# 9895                                 0.0                            0.0
# 9896                                 0.0                            0.0
# 9897                                 1.0                            1.0
# 9898                                 0.0                            0.0
# 9899                                 1.0                            1.0
#
#       Jaccard Index Similarity  Longest Maximal Independent Set  \
# 9895                       0.0                               61
# 9896                       0.0                               61
# 9897                       0.0                               61
# 9898                       0.0                               61
# 9899                       0.0                               61
#
#       Number of Maximal Cliques  Longest Maximal Clique
# 9895                     613800                       3
# 9896                     613800                       3
# 9897                     613800                       3
# 9898                     613800                       3
# 9899                     613800                       3

# %%
dist_1.describe()
# Out:
#        Edit-Distance Immediate Similarity  Edit-Distance Full Similarity  \
# count                         9900.000000                    9900.000000
# mean                             0.228426                       0.431702
# std                              0.415298                       0.436127
# min                              0.000000                       0.000000
# 25%                              0.000000                       0.000000
# 50%                              0.000000                       0.247680
# 75%                              0.000000                       0.953078
# max                              1.000000                       1.000000
#
#        Jaccard Index Similarity  Longest Maximal Independent Set  \
# count               9900.000000                           9900.0
# mean                   0.034488                             61.0
# std                    0.105410                              0.0
# min                    0.000000                             61.0
# 25%                    0.000000                             61.0
# 50%                    0.000000                             61.0
# 75%                    0.015563                             61.0
# max                    0.958808                             61.0
#
#        Number of Maximal Cliques  Longest Maximal Clique
# count                     9900.0                  9900.0
# mean                    613800.0                     3.0
# std                          0.0                     0.0
# min                     613800.0                     3.0
# 25%                     613800.0                     3.0
# 50%                     613800.0                     3.0
# 75%                     613800.0                     3.0
# max                     613800.0                     3.0

# %%
dist_1.boxplot(column=["Edit-Distance Immediate Similarity", "Edit-Distance Full Similarity", 'Jaccard Index Similarity'], figsize = (10,8), return_type = "axes")

plt.ylabel("Similarity")
plt.xlabel("(Using a Randomly Generated Directed Graphical Models with 100 nodes and 150 edges)")
plt.title("Similarity of Nodes in a Single Directed Graphical Model")
# plt.ylim(0, 1)
plt.savefig('Experiment - Similarity Distribution of Nodes/sim-dist-nodes-100-150_1.png')

# %%
dist_2 = pd.read_csv("Experiment - Similarity Distribution of Nodes/Data/sim-dist-nodes-100-150_2.csv", header=[0], index_col=[0])

# %%
dist_2.describe()
# Out:
#        Edit-Distance Immediate Similarity  Edit-Distance Full Similarity  \
# count                         9900.000000                    9900.000000
# mean                             0.227754                       0.513638
# std                              0.414671                       0.430707
# min                              0.000000                       0.000000
# 25%                              0.000000                       0.000000
# 50%                              0.000000                       0.632712
# 75%                              0.000000                       0.977462
# max                              1.000000                       1.000000
#
#        Jaccard Index Similarity  Longest Maximal Independent Set  \
# count               9900.000000                           9900.0
# mean                   0.101357                             62.0
# std                    0.189824                              0.0
# min                    0.000000                             62.0
# 25%                    0.000000                             62.0
# 50%                    0.002482                             62.0
# 75%                    0.073948                             62.0
# max                    0.992502                             62.0
#
#        Number of Maximal Cliques  Longest Maximal Clique
# count                     9900.0                  9900.0
# mean                    603900.0                     2.0
# std                          0.0                     0.0
# min                     603900.0                     2.0
# 25%                     603900.0                     2.0
# 50%                     603900.0                     2.0
# 75%                     603900.0                     2.0
# max                     603900.0                     2.0

# %%
dist_2.boxplot(column=["Edit-Distance Immediate Similarity", "Edit-Distance Full Similarity", 'Jaccard Index Similarity'], figsize = (10,8), return_type = "axes")

plt.ylabel("Similarity")
plt.xlabel("(Using a Randomly Generated Directed Graphical Models with 100 nodes and 150 edges)")
plt.title("Similarity of Nodes in a Single Directed Graphical Model")
# plt.ylim(0, 1)
plt.savefig('Experiment - Similarity Distribution of Nodes/sim-dist-nodes-100-150_2.png')

# %% [markdown]
# ## Similarity Distribution of Graphs

# %%
dist_1 = pd.read_csv("Experiment - Similarity Distribution/Data/sim-dist-50-100-150.csv", header=[0, 1], index_col=[0])
dist_1.head()
# Out:
#              Edit-Distance Immediate Similarity                 \
#                                            mean  50%       std
# Graph Number
# 0                                      0.227481  0.0  0.415333
# 1                                      0.287256  0.0  0.448845
# 2                                      0.335536  0.0  0.468931
# 3                                      0.187555  0.0  0.386164
# 4                                      0.266849  0.0  0.438538
#
#              Edit-Distance Full Similarity                      \
#                                       mean       50%       std
# Graph Number
# 0                                 0.397798  0.131978  0.438687
# 1                                 0.531773  0.665918  0.430846
# 2                                 0.543423  0.717803  0.451999
# 3                                 0.456466  0.397049  0.428929
# 4                                 0.456660  0.331893  0.443897
#
#              Jaccard Index Similarity                 \
#                                  mean  50%       std
# Graph Number
# 0                            0.034769  0.0  0.102185
# 1                            0.065983  0.0  0.136669
# 2                            0.074722  0.0  0.162688
# 3                            0.048459  0.0  0.116549
# 4                            0.030799  0.0  0.089122
#
#              Longest Maximal Independent Set             \
#                                         mean   50%  std
# Graph Number
# 0                                       62.0  62.0  0.0
# 1                                       67.0  67.0  0.0
# 2                                       62.0  62.0  0.0
# 3                                       64.0  64.0  0.0
# 4                                       54.0  54.0  0.0
#
#              Number of Maximal Cliques                Longest Maximal Clique  \
#                                   mean       50%  std                   mean
# Graph Number
# 0                             584100.0  584100.0  0.0                    3.0
# 1                             653400.0  653400.0  0.0                    3.0
# 2                             603900.0  603900.0  0.0                    2.0
# 3                             594000.0  594000.0  0.0                    3.0
# 4                             584100.0  584100.0  0.0                    2.0
#
#
#               50%  std
# Graph Number
# 0             3.0  0.0
# 1             3.0  0.0
# 2             2.0  0.0
# 3             3.0  0.0
# 4             2.0  0.0

# %%
main_col_list = list({col_pair[0] for col_pair in dist_1.columns})
mean_data = {}

for col in main_col_list:
    mean_data[col] = dist_1[(col, "mean")]

mean_dist_1 = pd.DataFrame(data = mean_data)

# %%
mean_dist_1.head()
# Out:
#               Longest Maximal Clique  Jaccard Index Similarity  \
# Graph Number
# 0                                3.0                  0.034769
# 1                                3.0                  0.065983
# 2                                2.0                  0.074722
# 3                                3.0                  0.048459
# 4                                2.0                  0.030799
#
#               Longest Maximal Independent Set  Number of Maximal Cliques  \
# Graph Number
# 0                                        62.0                   584100.0
# 1                                        67.0                   653400.0
# 2                                        62.0                   603900.0
# 3                                        64.0                   594000.0
# 4                                        54.0                   584100.0
#
#               Edit-Distance Immediate Similarity  \
# Graph Number
# 0                                       0.227481
# 1                                       0.287256
# 2                                       0.335536
# 3                                       0.187555
# 4                                       0.266849
#
#               Edit-Distance Full Similarity
# Graph Number
# 0                                  0.397798
# 1                                  0.531773
# 2                                  0.543423
# 3                                  0.456466
# 4                                  0.456660

# %%
mean_dist_1.boxplot(column=["Edit-Distance Immediate Similarity", "Edit-Distance Full Similarity", 'Jaccard Index Similarity'], figsize = (10, 8), return_type = "axes")

plt.ylabel("Similarity")
plt.xlabel("(Using 50 Randomly Generated Directed Graphical Models with 100 nodes and 150 edges)")
plt.title("Similarity of Randomly Generated Directed Graphical Models")
plt.ylim(0, 1)
plt.savefig('Experiment - Similarity Distribution/sim-dist-50-100-150.png')

# %%
dist_2 = pd.read_csv("Experiment - Similarity Distribution/Data/sim-dist-50-100-150.csv", header=[0, 1], index_col=[0])
dist_2.head()
# Out:
#              Edit-Distance Immediate Similarity                 \
#                                            mean  50%       std
# Graph Number
# 0                                      0.227481  0.0  0.415333
# 1                                      0.287256  0.0  0.448845
# 2                                      0.335536  0.0  0.468931
# 3                                      0.187555  0.0  0.386164
# 4                                      0.266849  0.0  0.438538
#
#              Edit-Distance Full Similarity                      \
#                                       mean       50%       std
# Graph Number
# 0                                 0.397798  0.131978  0.438687
# 1                                 0.531773  0.665918  0.430846
# 2                                 0.543423  0.717803  0.451999
# 3                                 0.456466  0.397049  0.428929
# 4                                 0.456660  0.331893  0.443897
#
#              Jaccard Index Similarity                 \
#                                  mean  50%       std
# Graph Number
# 0                            0.034769  0.0  0.102185
# 1                            0.065983  0.0  0.136669
# 2                            0.074722  0.0  0.162688
# 3                            0.048459  0.0  0.116549
# 4                            0.030799  0.0  0.089122
#
#              Longest Maximal Independent Set             \
#                                         mean   50%  std
# Graph Number
# 0                                       62.0  62.0  0.0
# 1                                       67.0  67.0  0.0
# 2                                       62.0  62.0  0.0
# 3                                       64.0  64.0  0.0
# 4                                       54.0  54.0  0.0
#
#              Number of Maximal Cliques                Longest Maximal Clique  \
#                                   mean       50%  std                   mean
# Graph Number
# 0                             584100.0  584100.0  0.0                    3.0
# 1                             653400.0  653400.0  0.0                    3.0
# 2                             603900.0  603900.0  0.0                    2.0
# 3                             594000.0  594000.0  0.0                    3.0
# 4                             584100.0  584100.0  0.0                    2.0
#
#
#               50%  std
# Graph Number
# 0             3.0  0.0
# 1             3.0  0.0
# 2             2.0  0.0
# 3             3.0  0.0
# 4             2.0  0.0

# %%
main_col_list = list({col_pair[0] for col_pair in dist_2.columns})
mean_data = {}

for col in main_col_list:
    mean_data[col] = dist_2[(col, "mean")]

mean_dist_2 = pd.DataFrame(data = mean_data)

# %%
mean_dist_2.boxplot(column=["Edit-Distance Immediate Similarity", "Edit-Distance Full Similarity", 'Jaccard Index Similarity'], figsize = (10,8), return_type = "axes")

plt.ylabel("Similarity")
plt.xlabel("(Using 50 Randomly Generated Directed Graphical Models with 100 nodes and 150 edges)")
plt.title("Similarity of Randomly Generated Directed Graphical Models")
plt.ylim(0, 1)
plt.savefig('Experiment - Similarity Distribution/sim-dist-50-100-150.png')

# %% [markdown]
# ## Similarity Distribution Over Varying Graph Sizes

# %%
dist = pd.read_csv("Experiment - Graph Size Distribution/Data/graph-size-dist-20-10-101-10.csv", header=[0, 1], index_col=[0,1])
dist.head()
# Out:
#                                            Edit-Distance Immediate Similarity  \
#                                                                          mean
# Number of Nodes Per Graph Number of Graphs
# 10                        20                                         0.457820
# 20                        20                                         0.415751
# 30                        20                                         0.405051
# 40                        20                                         0.391466
# 50                        20                                         0.380057
#
#                                                                 \
#                                                  50%       std
# Number of Nodes Per Graph Number of Graphs
# 10                        20                0.445231  0.087645
# 20                        20                0.410064  0.073209
# 30                        20                0.407400  0.050283
# 40                        20                0.389773  0.043012
# 50                        20                0.375681  0.045034
#
#                                            Edit-Distance Full Similarity  \
#                                                                     mean
# Number of Nodes Per Graph Number of Graphs
# 10                        20                                    0.558010
# 20                        20                                    0.501440
# 30                        20                                    0.490946
# 40                        20                                    0.480303
# 50                        20                                    0.460260
#
#                                                                 \
#                                                  50%       std
# Number of Nodes Per Graph Number of Graphs
# 10                        20                0.563976  0.060386
# 20                        20                0.497574  0.053639
# 30                        20                0.495607  0.047538
# 40                        20                0.487184  0.030674
# 50                        20                0.456052  0.042055
#
#                                            Jaccard Index Similarity            \
#                                                                mean       50%
# Number of Nodes Per Graph Number of Graphs
# 10                        20                               0.033027  0.026460
# 20                        20                               0.028894  0.022020
# 30                        20                               0.027204  0.021423
# 40                        20                               0.025620  0.023947
# 50                        20                               0.020918  0.016476
#
#                                                       \
#                                                  std
# Number of Nodes Per Graph Number of Graphs
# 10                        20                0.025791
# 20                        20                0.019757
# 30                        20                0.015185
# 40                        20                0.012670
# 50                        20                0.014328
#
#                                            Longest Maximal Independent Set  \
#                                                                       mean
# Number of Nodes Per Graph Number of Graphs
# 10                        20                                          7.30
# 20                        20                                         13.80
# 30                        20                                         21.30
# 40                        20                                         28.70
# 50                        20                                         34.65
#
#                                                             \
#                                              50%       std
# Number of Nodes Per Graph Number of Graphs
# 10                        20                 7.0  0.978721
# 20                        20                14.0  1.196486
# 30                        20                21.5  1.559352
# 40                        20                29.0  1.260743
# 50                        20                34.0  1.785173
#
#                                            Number of Maximal Cliques           \
#                                                                 mean      50%
# Number of Nodes Per Graph Number of Graphs
# 10                        20                                   580.5    540.0
# 20                        20                                  4864.0   4940.0
# 30                        20                                 16704.0  16530.0
# 40                        20                                 40794.0  40560.0
# 50                        20                                 78645.0  78400.0
#
#                                                          \
#                                                     std
# Number of Nodes Per Graph Number of Graphs
# 10                        20                  54.432479
# 20                        20                 361.552209
# 30                        20                 918.989147
# 40                        20                1912.277232
# 50                        20                3068.297145
#
#                                            Longest Maximal Clique       \
#                                                              mean  50%
# Number of Nodes Per Graph Number of Graphs
# 10                        20                                 2.30  2.0
# 20                        20                                 2.35  2.0
# 30                        20                                 2.45  2.0
# 40                        20                                 2.20  2.0
# 50                        20                                 2.25  2.0
#
#
#                                                  std
# Number of Nodes Per Graph Number of Graphs
# 10                        20                0.470162
# 20                        20                0.489360
# 30                        20                0.510418
# 40                        20                0.410391
# 50                        20                0.444262

# %%
# dist_1 = pd.read_csv("Experiment - Graph Size Distribution/Data/graph-size-dist-20-10-41-10.csv", header=[0, 1], index_col=[0,1])
# dist_2 = pd.read_csv("Experiment - Graph Size Distribution/Data/graph-size-dist-10-70-101-10.csv", header=[0, 1], index_col=[0,1])
# dist_2.head()

# %%
# distributions = [dist_1, dist_2]

# dist = pd.concat(distributions)

# %%
# dist["Edit-Distance Immediate Similarity"]["mean"]

# %%
fig = plt.figure(figsize = (12, 8))
ax = fig.add_subplot(111)

ed_imm_sim = list(dist["Edit-Distance Immediate Similarity"]["mean"])
ed_f_sim = list(dist["Edit-Distance Full Similarity"]["mean"])
ji_sim = list(dist["Jaccard Index Similarity"]["mean"])

ed_imm_sim_std = list(dist["Edit-Distance Immediate Similarity"]["std"])
ed_f_sim_std = list(dist["Edit-Distance Full Similarity"]["std"])
ji_sim_std = list(dist["Jaccard Index Similarity"]["std"])

# Adapted from https://stackoverflow.com/questions/14270391/python-matplotlib-multiple-bars
N = len(ed_imm_sim)
ind = np.arange(N)  # the x locations for the groups
width = 0.27       # the width of the bars
index_1_list = [value_pair[0] for value_pair in dist.index.values.tolist()]

# ed_imm_sim = dist["Edit-Distance Immediate Similarity"]["mean"]
# ed_f_sim = dist["Edit-Distance Full Similarity"]["mean"]
# ji_sim = dist["Jaccard Index Similarity"]["mean"]

# ed_imm_sim_std = dist["Edit-Distance Immediate Similarity"]["std"]
# ed_f_sim_std = dist["Edit-Distance Full Similarity"]["std"]
# ji_sim_std = dist["Jaccard Index Similarity"]["std"]

# print(ji_sim_std.shape == ji_sim.shape)
# print(len(ed_imm_sim) == len(ji_sim_std))

rects1 = ax.bar(ind, ed_imm_sim, width, color='r', yerr=ed_imm_sim_std)
rects2 = ax.bar(ind + width, ed_f_sim, width, color='g', yerr=ed_f_sim_std)
rects3 = ax.bar(ind + width * 2, ji_sim, width, color='b', yerr=ji_sim_std)

ax.set_ylabel('Similarity')
ax.set_xlabel("Graph Size (Number of Nodes)")
ax.set_xticks(ind + width)
ax.set_xticklabels(index_1_list)
ax.legend((rects1[0], rects2[0], rects3[0]), ('Edit-Distance Immediate Similarity', 'Edit-Distance Full Similarity', 'Jaccard Index Similarity'))
ax.set_ylim(0, 1)
ax.set_title("Similarity vs. Graph Size")

plt.savefig("Experiment - Graph Size Distribution/graph-size-dist-20-10-101-10.png")

plt.show()

# %% [markdown]
# ## Similarity Distribution Over Edge Factor

# %%
dist = pd.read_csv("Experiment - Edges Factor/Data/edges-factor-dist-10-40-1.0-3.1-0.5.csv", header=[0, 1], index_col=[0,1,2,3])
dist.head()
# Out:
#                                                                                            Edit-Distance Immediate Similarity  \
#                                                                                                                          mean
# Nodes To Edges Factor Number of Nodes Per Graph Number of Edges Per Graph Number of Graphs
# 1.0                   40                        40                        10                                         0.405759
# 1.5                   40                        60                        10                                         0.302746
# 2.0                   40                        80                        10                                         0.205094
# 2.5                   40                        100                       10                                         0.168500
# 3.0                   40                        120                       10                                         0.160983
#
#                                                                                                       \
#                                                                                                  50%
# Nodes To Edges Factor Number of Nodes Per Graph Number of Edges Per Graph Number of Graphs
# 1.0                   40                        40                        10                0.411262
# 1.5                   40                        60                        10                0.289327
# 2.0                   40                        80                        10                0.200993
# 2.5                   40                        100                       10                0.173305
# 3.0                   40                        120                       10                0.154390
#
#                                                                                                       \
#                                                                                                  std
# Nodes To Edges Factor Number of Nodes Per Graph Number of Edges Per Graph Number of Graphs
# 1.0                   40                        40                        10                0.044490
# 1.5                   40                        60                        10                0.061512
# 2.0                   40                        80                        10                0.023451
# 2.5                   40                        100                       10                0.037072
# 3.0                   40                        120                       10                0.042684
#
#                                                                                            Edit-Distance Full Similarity  \
#                                                                                                                     mean
# Nodes To Edges Factor Number of Nodes Per Graph Number of Edges Per Graph Number of Graphs
# 1.0                   40                        40                        10                                    0.476995
# 1.5                   40                        60                        10                                    0.502165
# 2.0                   40                        80                        10                                    0.541620
# 2.5                   40                        100                       10                                    0.587295
# 3.0                   40                        120                       10                                    0.588472
#
#                                                                                                       \
#                                                                                                  50%
# Nodes To Edges Factor Number of Nodes Per Graph Number of Edges Per Graph Number of Graphs
# 1.0                   40                        40                        10                0.470742
# 1.5                   40                        60                        10                0.500352
# 2.0                   40                        80                        10                0.530378
# 2.5                   40                        100                       10                0.578619
# 3.0                   40                        120                       10                0.588879
#
#                                                                                                       \
#                                                                                                  std
# Nodes To Edges Factor Number of Nodes Per Graph Number of Edges Per Graph Number of Graphs
# 1.0                   40                        40                        10                0.032889
# 1.5                   40                        60                        10                0.066793
# 2.0                   40                        80                        10                0.046672
# 2.5                   40                        100                       10                0.038382
# 3.0                   40                        120                       10                0.038583
#
#                                                                                            Jaccard Index Similarity  \
#                                                                                                                mean
# Nodes To Edges Factor Number of Nodes Per Graph Number of Edges Per Graph Number of Graphs
# 1.0                   40                        40                        10                               0.022285
# 1.5                   40                        60                        10                               0.056702
# 2.0                   40                        80                        10                               0.110087
# 2.5                   40                        100                       10                               0.150117
# 3.0                   40                        120                       10                               0.141238
#
#                                                                                                       \
#                                                                                                  50%
# Nodes To Edges Factor Number of Nodes Per Graph Number of Edges Per Graph Number of Graphs
# 1.0                   40                        40                        10                0.019949
# 1.5                   40                        60                        10                0.042762
# 2.0                   40                        80                        10                0.101060
# 2.5                   40                        100                       10                0.152204
# 3.0                   40                        120                       10                0.133154
#
#                                                                                                       \
#                                                                                                  std
# Nodes To Edges Factor Number of Nodes Per Graph Number of Edges Per Graph Number of Graphs
# 1.0                   40                        40                        10                0.011625
# 1.5                   40                        60                        10                0.042916
# 2.0                   40                        80                        10                0.025362
# 2.5                   40                        100                       10                0.040081
# 3.0                   40                        120                       10                0.037027
#
#                                                                                            Longest Maximal Independent Set  \
#                                                                                                                       mean
# Nodes To Edges Factor Number of Nodes Per Graph Number of Edges Per Graph Number of Graphs
# 1.0                   40                        40                        10                                          28.8
# 1.5                   40                        60                        10                                          25.9
# 2.0                   40                        80                        10                                          23.5
# 2.5                   40                        100                       10                                          20.8
# 3.0                   40                        120                       10                                          21.0
#
#                                                                                                   \
#                                                                                              50%
# Nodes To Edges Factor Number of Nodes Per Graph Number of Edges Per Graph Number of Graphs
# 1.0                   40                        40                        10                28.5
# 1.5                   40                        60                        10                26.0
# 2.0                   40                        80                        10                23.0
# 2.5                   40                        100                       10                21.0
# 3.0                   40                        120                       10                21.0
#
#                                                                                                       \
#                                                                                                  std
# Nodes To Edges Factor Number of Nodes Per Graph Number of Edges Per Graph Number of Graphs
# 1.0                   40                        40                        10                1.229273
# 1.5                   40                        60                        10                2.024846
# 2.0                   40                        80                        10                1.649916
# 2.5                   40                        100                       10                1.751190
# 3.0                   40                        120                       10                1.333333
#
#                                                                                            Number of Maximal Cliques  \
#                                                                                                                 mean
# Nodes To Edges Factor Number of Nodes Per Graph Number of Edges Per Graph Number of Graphs
# 1.0                   40                        40                        10                                 40092.0
# 1.5                   40                        60                        10                                 37596.0
# 2.0                   40                        80                        10                                 35256.0
# 2.5                   40                        100                       10                                 33384.0
# 3.0                   40                        120                       10                                 31200.0
#
#                                                                                                      \
#                                                                                                 50%
# Nodes To Edges Factor Number of Nodes Per Graph Number of Edges Per Graph Number of Graphs
# 1.0                   40                        40                        10                39780.0
# 1.5                   40                        60                        10                37440.0
# 2.0                   40                        80                        10                35880.0
# 2.5                   40                        100                       10                32760.0
# 3.0                   40                        120                       10                31200.0
#
#                                                                                                          \
#                                                                                                     std
# Nodes To Edges Factor Number of Nodes Per Graph Number of Edges Per Graph Number of Graphs
# 1.0                   40                        40                        10                1652.585853
# 1.5                   40                        60                        10                2137.699698
# 2.0                   40                        80                        10                2105.839500
# 2.5                   40                        100                       10                1973.261260
# 3.0                   40                        120                       10                1801.332840
#
#                                                                                            Longest Maximal Clique  \
#                                                                                                              mean
# Nodes To Edges Factor Number of Nodes Per Graph Number of Edges Per Graph Number of Graphs
# 1.0                   40                        40                        10                                  2.5
# 1.5                   40                        60                        10                                  2.8
# 2.0                   40                        80                        10                                  2.9
# 2.5                   40                        100                       10                                  3.0
# 3.0                   40                        120                       10                                  3.0
#
#                                                                                                  \
#                                                                                             50%
# Nodes To Edges Factor Number of Nodes Per Graph Number of Edges Per Graph Number of Graphs
# 1.0                   40                        40                        10                2.5
# 1.5                   40                        60                        10                3.0
# 2.0                   40                        80                        10                3.0
# 2.5                   40                        100                       10                3.0
# 3.0                   40                        120                       10                3.0
#
#
#                                                                                                  std
# Nodes To Edges Factor Number of Nodes Per Graph Number of Edges Per Graph Number of Graphs
# 1.0                   40                        40                        10                0.527046
# 1.5                   40                        60                        10                0.421637
# 2.0                   40                        80                        10                0.567646
# 2.5                   40                        100                       10                0.000000
# 3.0                   40                        120                       10                0.000000

# %%
fig = plt.figure(figsize = (12, 8))
ax = fig.add_subplot(111)

ed_imm_sim = list(dist["Edit-Distance Immediate Similarity"]["mean"])
ed_f_sim = list(dist["Edit-Distance Full Similarity"]["mean"])
ji_sim = list(dist["Jaccard Index Similarity"]["mean"])

ed_imm_sim_std = list(dist["Edit-Distance Immediate Similarity"]["std"])
ed_f_sim_std = list(dist["Edit-Distance Full Similarity"]["std"])
ji_sim_std = list(dist["Jaccard Index Similarity"]["std"])

# Adapted from https://stackoverflow.com/questions/14270391/python-matplotlib-multiple-bars
N = len(ed_imm_sim)
ind = np.arange(N)  # the x locations for the groups
width = 0.27       # the width of the bars
index_1_list = [value_pair[0] for value_pair in dist.index.values.tolist()]

rects1 = ax.bar(ind, ed_imm_sim, width, color='r', yerr=ed_imm_sim_std)
rects2 = ax.bar(ind + width, ed_f_sim, width, color='g', yerr=ed_f_sim_std)
rects3 = ax.bar(ind + width * 2, ji_sim, width, color='b', yerr=ji_sim_std)

ax.set_ylabel('Similarity')
ax.set_xlabel("Nodes To Edges Factor")
ax.set_xticks(ind + width)
ax.set_xticklabels(index_1_list)
ax.legend((rects1[0], rects2[0], rects3[0]), ('Edit-Distance Immediate Similarity', 'Edit-Distance Full Similarity', 'Jaccard Index Similarity'))
ax.set_ylim(0, 1)
ax.set_title("Similarity vs. Nodes To Edges Factor")

plt.savefig("Experiment - Edges Factor/edges-factor-dist-10-40-1.0-3.1-0.5.png")

plt.show()
